# %%
import csv
import uuid
import stardog

#create a new variable called 'outfile' (could be any name), which we'll use to create a new file that we'll pass our TTL into.
outfile = open('MiscServices.ttl', 'a',encoding='latin-1')

with open('C:/Users/ekjot/Downloads/allMiscServicesCombined.csv', 'r',encoding='latin-1') as read_obj:
    Reader = csv.reader(read_obj)
#ifile = open('councils-data.csv', 'rb')
#reader = csv.reader(ifile)

#create a new variable called 'outfile' (could be any name), which we'll use to create a new file that we'll pass our TTL into.
    

    #get python to loop through each row in the CSV, and ignore the first row.
    query = """
        @prefix : <http://api.stardog.com/> .
        @prefix stardog: <tag:stardog:api:> .
        @prefix owl: <http://www.w3.org/2002/07/owl#> .
        @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
        @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
        @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

        """
    rownum = 0
    for row in Reader:
        if rownum == 0:
            pass
        else:
            c = row
            prefix = "<http://api.stardog.comMiscServices#" + str(uuid.uuid1()) + "> "
            postfix = " <http://api.stardog.comMiscServices> ;"
            output = prefix + "a" + postfix
            output = output +"\n\t:hasPrice    " + str(row[6]) + ";\n\t:hasService \"" + row[8] + "\" ;\n"
            output = output + "\t:hasLocation \"" + row[1] + "\" ;\n" + "\t:hasLandmark \"" + row[3] + "\" ;\n" + "\t:hasName \"" + row[0] + "\" ;\n" + "\t:hasAddress \"" + row[2] + "\" ;\n" + "\t:hasLatitude " + str(row[5]) + " ;\n" + "\t:hasLongitude " + str(row[4]) + " ;\n" + "\t:hasPhone " + str(row[7]) + " .\n"
            print(output)
            outfile.write(output)
        rownum += 1
    outfile.close()
#ifile.close()
# Out:
# <http://api.stardog.comMiscServices#8dff38cf-84c3-11ec-b161-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    545;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "MEELAS By Gbappa" ;
# 	:hasAddress "Viento 14, Lakeshore Greens,, Taloja By Pass Road, Khoni, Thane - 421204, Lodha Palava 2" ;
# 	:hasLatitude 8.8046 ;
# 	:hasLongitude 965.910532395355 ;
# 	:hasPhone 6298956461 .
#
# <http://api.stardog.comMiscServices#8dff5fcd-84c3-11ec-9002-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1448;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Pramanik Provision Stores" ;
# 	:hasAddress "Shop No 658, Tardeo Road, Tardeo, Mumbai - 400034, Opposite Bhatiya Hospital, Kailash Nagar" ;
# 	:hasLatitude 20.2268 ;
# 	:hasLongitude 263.67696269881 ;
# 	:hasPhone 6456598722 .
#
# <http://api.stardog.comMiscServices#8dff5fce-84c3-11ec-937e-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1675;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Rakhangi General Stores Nx" ;
# 	:hasAddress "Plot No 2, Kakad Estate, R G Thadani Marg, Worli, Mumbai - 400018" ;
# 	:hasLatitude 20.6001 ;
# 	:hasLongitude 734.112939680927 ;
# 	:hasPhone 5689397146 .
#
# <http://api.stardog.comMiscServices#8dff5fcf-84c3-11ec-8420-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1604;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "401107, Opp. Amber Plaza, Mira Road, Maharashtra 401107" ;
# 	:hasName "Marketplace" ;
# 	:hasAddress "Shop No. 2, Satyam Heritage,, Opp. Amber Plaza, Vijay Park,, Mira Road, Thane - 401107, Opp. Amber Plaza, Mira Road, Maharashtra 401107" ;
# 	:hasLatitude 58.3504 ;
# 	:hasLongitude 761.632836307399 ;
# 	:hasPhone 3007801874 .
#
# <http://api.stardog.comMiscServices#8dff8700-84c3-11ec-ae20-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    954;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Khetlaji Super Market" ;
# 	:hasAddress "Shop No 8, Swastik Regalia Building, Waghbil-thane West, Thane - 400607" ;
# 	:hasLatitude 62.9993 ;
# 	:hasLongitude 942.156676785089 ;
# 	:hasPhone 8058191461 .
#
# <http://api.stardog.comMiscServices#8dff8701-84c3-11ec-a62f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    521;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Bawadi" ;
# 	:hasName "S P Super Bazar" ;
# 	:hasAddress "Shop No 98 Aadarsh Nagar Old Hill Qutres, Aarey Road, Goregaon East, Mumbai - 400065, Near Bawadi" ;
# 	:hasLatitude 97.9395 ;
# 	:hasLongitude 381.275366875343 ;
# 	:hasPhone 5881968114 .
#
# <http://api.stardog.comMiscServices#8dff8702-84c3-11ec-b4a2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    555;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "KharRailway" ;
# 	:hasName "CHHEDAS" ;
# 	:hasAddress "Shop No 7, Ajanta Building, 3rd Cross Road,, Khar West, Mumbai - 400052, Ram Krishna Nagar  Near Khar Railway" ;
# 	:hasLatitude 12.2563 ;
# 	:hasLongitude 313.653102959506 ;
# 	:hasPhone 8095118844 .
#
# <http://api.stardog.comMiscServices#8dff8703-84c3-11ec-964e-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1003;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Sambhaji Chowk" ;
# 	:hasName "A 1 Super Market" ;
# 	:hasAddress "Surya Nagar ,, Ahilyabai Holkar Road, Vikhroli West, Mumbai - 400083, Opposite Shiv Sena Office, Sambhaji Chowk" ;
# 	:hasLatitude 72.4483 ;
# 	:hasLongitude 639.014494488947 ;
# 	:hasPhone 7193194234 .
#
# <http://api.stardog.comMiscServices#8dff8704-84c3-11ec-be74-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1172;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Railway Reservation Counter" ;
# 	:hasName "Jai Bhawani Masala Mill" ;
# 	:hasAddress "Shop No.2, Ganga Chaya Building, Station Road, Bhayander East, Thane - 401105, Opp.Railway Reservation Counter" ;
# 	:hasLatitude 39.579 ;
# 	:hasLongitude 581.450619152747 ;
# 	:hasPhone 1656943651 .
#
# <http://api.stardog.comMiscServices#8dff8705-84c3-11ec-a64f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1251;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Shiv Dairy" ;
# 	:hasName "Gupta Store" ;
# 	:hasAddress "Shop No 13, Sion Koliwada, Sion Koliwada, Mumbai - 400022, Behind Hazara Hotel and Besides Shiv Dairy ." ;
# 	:hasLatitude 97.8318 ;
# 	:hasLongitude 186.601183959283 ;
# 	:hasPhone 6097400788 .
#
# <http://api.stardog.comMiscServices#8dff8706-84c3-11ec-81f0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1300;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Sibbu Palace" ;
# 	:hasName "Shiv Shankar Dryfruit" ;
# 	:hasAddress "Shop-7/17,Parwati Commercial,Shivdham Complex, Station Road, Ambernath, Thane - 421501, Near Sibbu Palace" ;
# 	:hasLatitude 47.6806 ;
# 	:hasLongitude 491.79302866105 ;
# 	:hasPhone 2743038523 .
#
# <http://api.stardog.comMiscServices#8dff8707-84c3-11ec-963d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    838;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Phata" ;
# 	:hasName "Vainkho Groceries" ;
# 	:hasAddress "Warehouse No. 4, Sarvodya Nagar,, Jambul Road, Ambernath West, Ambernath, Thane - 421505, Jambul Phata" ;
# 	:hasLatitude 33.4822 ;
# 	:hasLongitude 706.168073811568 ;
# 	:hasPhone 3609513465 .
#
# <http://api.stardog.comMiscServices#8dff8708-84c3-11ec-b732-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1116;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Prabhadevi Railway Station" ;
# 	:hasName "Mauli Super Market" ;
# 	:hasAddress "Shop No 33, Ground Floor,, Bhau Saheb Todankar Road, Prabhadevi, Mumbai - 400013, Near Prabhadevi Railway Station" ;
# 	:hasLatitude 97.7532 ;
# 	:hasLongitude 990.880208206363 ;
# 	:hasPhone 5087388667 .
#
# <http://api.stardog.comMiscServices#8dff8709-84c3-11ec-8807-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1612;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "umbai" ;
# 	:hasName "The Rakhangi General Store" ;
# 	:hasAddress "Shop No. 4, Ratna Shree Opp Crompton Greaves Office, Century Bazar Worli, Worli Sea Face, Mumbai - 400030" ;
# 	:hasLatitude 67.4203 ;
# 	:hasLongitude 930.799989611842 ;
# 	:hasPhone 7619562576 .
#
# <http://api.stardog.comMiscServices#8dffae16-84c3-11ec-a3e8-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    679;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Section 32. Ulhasnagar 4, Kaly, Maratha Section-32, Ulhasnagar No 4, Thane - 421004, Ashirwad Hospital" ;
# 	:hasName "Victors Mart" ;
# 	:hasAddress "Direct No. 1381, Room NO. 8, Shop NO.1, NEar Ashirwad Hospital Marata Section 32. Ulhasnagar 4, Kaly, Maratha Section-32, Ulhasnagar No 4, Thane - 421004, Ashirwad Hospital" ;
# 	:hasLatitude 20.6712 ;
# 	:hasLongitude 36.952088936232 ;
# 	:hasPhone 5462248199 .
#
# <http://api.stardog.comMiscServices#8dffae17-84c3-11ec-8df5-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    665;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "AgashiPeeth" ;
# 	:hasName "Dedhia Stores" ;
# 	:hasAddress "Shop Number 4 & 5, Radhakrishna Bhuvan, Arnala Road, Agashi, Palghar - 401301, Opposite Canara Bank, Near Agashi Baazar Peeth" ;
# 	:hasLatitude 63.4499 ;
# 	:hasLongitude 604.653140413575 ;
# 	:hasPhone 2219094619 .
#
# <http://api.stardog.comMiscServices#8dffae18-84c3-11ec-bcd7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1392;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Near Sant Jalaram Bappa Market" ;
# 	:hasName "Oswal Supermarket" ;
# 	:hasAddress "Mr Chintan Chheda, S L Road, Mulund West, Mumbai - 400080, Opposite to Station ,Near Sant Jalaram Bappa Market" ;
# 	:hasLatitude 5.5542 ;
# 	:hasLongitude 637.028247001581 ;
# 	:hasPhone 8114917834 .
#
# <http://api.stardog.comMiscServices#8dffae19-84c3-11ec-ba2a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1656;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "East, Mumbai - 400097, Opposite Jain Temple, Near Western Express Highway" ;
# 	:hasName "M B Mart" ;
# 	:hasAddress "Plot No A-1, A-2, Thavar Madan Chawl, Jain Temple Road, Malad East, Mumbai - 400097, Opposite Jain Temple, Near Western Express Highway" ;
# 	:hasLatitude 59.3754 ;
# 	:hasLongitude 229.684121790342 ;
# 	:hasPhone 5538172306 .
#
# <http://api.stardog.comMiscServices#8dffd505-84c3-11ec-a064-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1721;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Grrovers Supermart" ;
# 	:hasAddress "Shop No 17, Krypton Terrace, Sayani Road, Prabhadevi, Mumbai - 400025" ;
# 	:hasLatitude 16.4216 ;
# 	:hasLongitude 785.294590401463 ;
# 	:hasPhone 9656438014 .
#
# <http://api.stardog.comMiscServices#8dfffc1d-84c3-11ec-9723-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1934;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Behind Aadarsh College and Near Digi 1" ;
# 	:hasName "Shree Siddhanath Aapla Baza.." ;
# 	:hasAddress "Plot No. C-25, Mahada Colony, Sambhaji Nagar,, Badlapur East, Badlapur, Thane - 421503, Behind Aadarsh College and Near Digi 1" ;
# 	:hasLatitude 75.7608 ;
# 	:hasLongitude 939.506524824537 ;
# 	:hasPhone 7468306219 .
#
# <http://api.stardog.comMiscServices#8dfffc1e-84c3-11ec-9347-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1657;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Sibbu Palace" ;
# 	:hasName "Shiv Shankar Dryfruit" ;
# 	:hasAddress "Shop-7/17,Parwati Commercial,Shivdham Complex, Station Road, Ambernath, Thane - 421501, Near Sibbu Palace" ;
# 	:hasLatitude 26.3277 ;
# 	:hasLongitude 586.162189370953 ;
# 	:hasPhone 8794912893 .
#
# <http://api.stardog.comMiscServices#8dfffc1f-84c3-11ec-a530-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1161;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Phata" ;
# 	:hasName "Vainkho Groceries" ;
# 	:hasAddress "Warehouse No. 4, Sarvodya Nagar,, Jambul Road, Ambernath West, Ambernath, Thane - 421505, Jambul Phata" ;
# 	:hasLatitude 3.9276 ;
# 	:hasLongitude 82.7429190976545 ;
# 	:hasPhone 9790082231 .
#
# <http://api.stardog.comMiscServices#8dfffc20-84c3-11ec-ae86-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1138;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Prabhadevi Railway Station" ;
# 	:hasName "Mauli Super Market" ;
# 	:hasAddress "Shop No 33, Ground Floor,, Bhau Saheb Todankar Road, Prabhadevi, Mumbai - 400013, Near Prabhadevi Railway Station" ;
# 	:hasLatitude 41.2692 ;
# 	:hasLongitude 18.6859254026786 ;
# 	:hasPhone 4295607774 .
#
# <http://api.stardog.comMiscServices#8dfffc21-84c3-11ec-9f7e-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1689;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "umbai" ;
# 	:hasName "The Rakhangi General Store" ;
# 	:hasAddress "Shop No. 4, Ratna Shree Opp Crompton Greaves Office, Century Bazar Worli, Worli Sea Face, Mumbai - 400030" ;
# 	:hasLatitude 66.118 ;
# 	:hasLongitude 844.910596148111 ;
# 	:hasPhone 6995392438 .
#
# <http://api.stardog.comMiscServices#8dfffc22-84c3-11ec-af4f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1887;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Section 32. Ulhasnagar 4, Kaly, Maratha Section-32, Ulhasnagar No 4, Thane - 421004, Ashirwad Hospital" ;
# 	:hasName "Victors Mart" ;
# 	:hasAddress "Direct No. 1381, Room NO. 8, Shop NO.1, NEar Ashirwad Hospital Marata Section 32. Ulhasnagar 4, Kaly, Maratha Section-32, Ulhasnagar No 4, Thane - 421004, Ashirwad Hospital" ;
# 	:hasLatitude 94.1535 ;
# 	:hasLongitude 494.78945962619 ;
# 	:hasPhone 6348712105 .
#
# <http://api.stardog.comMiscServices#8dfffc23-84c3-11ec-bab1-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1504;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "AgashiPeeth" ;
# 	:hasName "Dedhia Stores" ;
# 	:hasAddress "Shop Number 4 & 5, Radhakrishna Bhuvan, Arnala Road, Agashi, Palghar - 401301, Opposite Canara Bank, Near Agashi Baazar Peeth" ;
# 	:hasLatitude 83.9427 ;
# 	:hasLongitude 573.605439509265 ;
# 	:hasPhone 7920525194 .
#
# <http://api.stardog.comMiscServices#8dfffc24-84c3-11ec-8349-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    644;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Near Sant Jalaram Bappa Market" ;
# 	:hasName "Oswal Supermarket" ;
# 	:hasAddress "Mr Chintan Chheda, S L Road, Mulund West, Mumbai - 400080, Opposite to Station ,Near Sant Jalaram Bappa Market" ;
# 	:hasLatitude 47.8232 ;
# 	:hasLongitude 105.127885588445 ;
# 	:hasPhone 7680834948 .
#
# <http://api.stardog.comMiscServices#8e002320-84c3-11ec-ac39-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    684;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "East, Mumbai - 400097, Opposite Jain Temple, Near Western Express Highway" ;
# 	:hasName "M B Mart" ;
# 	:hasAddress "Plot No A-1, A-2, Thavar Madan Chawl, Jain Temple Road, Malad East, Mumbai - 400097, Opposite Jain Temple, Near Western Express Highway" ;
# 	:hasLatitude 71.4721 ;
# 	:hasLongitude 555.620300932787 ;
# 	:hasPhone 6453584545 .
#
# <http://api.stardog.comMiscServices#8e002321-84c3-11ec-a568-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1203;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Grrovers Supermart" ;
# 	:hasAddress "Shop No 17, Krypton Terrace, Sayani Road, Prabhadevi, Mumbai - 400025" ;
# 	:hasLatitude 8.567 ;
# 	:hasLongitude 839.151322725229 ;
# 	:hasPhone 3006159130 .
#
# <http://api.stardog.comMiscServices#8e007153-84c3-11ec-ab22-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1706;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Behind Aadarsh College and Near Digi 1" ;
# 	:hasName "Shree Siddhanath Aapla Baza.." ;
# 	:hasAddress "Plot No. C-25, Mahada Colony, Sambhaji Nagar,, Badlapur East, Badlapur, Thane - 421503, Behind Aadarsh College and Near Digi 1" ;
# 	:hasLatitude 32.1096 ;
# 	:hasLongitude 895.195953431539 ;
# 	:hasPhone 8177270786 .
#
# <http://api.stardog.comMiscServices#8e007154-84c3-11ec-863e-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1566;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Suresh Stores" ;
# 	:hasAddress "Shop No.24, Ground Floor.   Galaxy Complex Sell Building, J W Road, Parel, Mumbai - 400012" ;
# 	:hasLatitude 95.9827 ;
# 	:hasLongitude 577.635761233978 ;
# 	:hasPhone 4650530296 .
#
# <http://api.stardog.comMiscServices#8e007155-84c3-11ec-a45f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1746;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Apka Super Market" ;
# 	:hasAddress "Sunil Nagar , Tukaram Nagar, Nandivali Road, Dombivli East, Thane - 421201, Near Nandivali Nala" ;
# 	:hasLatitude 62.906 ;
# 	:hasLongitude 746.983048389666 ;
# 	:hasPhone 6414387951 .
#
# <http://api.stardog.comMiscServices#8e007156-84c3-11ec-8e26-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    771;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "School, Virat Nagar" ;
# 	:hasName "Nakoda Super Market" ;
# 	:hasAddress "DEV Krupa Buildng, Shop No 1, 2&3, Virar West, Palghar - 401303, Opposite Vidyavihar School, Virat Nagar" ;
# 	:hasLatitude 48.1051 ;
# 	:hasLongitude 631.800574832596 ;
# 	:hasPhone 5671803250 .
#
# <http://api.stardog.comMiscServices#8e007157-84c3-11ec-b912-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1581;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400033, Near Abhyudaya Nagar, G D Ambedkar Marg" ;
# 	:hasName "Niti General Stores" ;
# 	:hasAddress "37 / 2602  G D Ambe Kar, G D Ambekar Marg, Kala Chowki, Mumbai - 400033, Near Abhyudaya Nagar, G D Ambedkar Marg" ;
# 	:hasLatitude 28.6839 ;
# 	:hasLongitude 323.873773100786 ;
# 	:hasPhone 9611930770 .
#
# <http://api.stardog.comMiscServices#8e00984e-84c3-11ec-ae6f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1738;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "mboli" ;
# 	:hasName "Here 4 U Pharmacy" ;
# 	:hasAddress "Shop No 5 Dlh Dream Tower Building, Jai Bhavani Mata Road, Andheri West, Mumbai - 400058, Amboli" ;
# 	:hasLatitude 49.4011 ;
# 	:hasLongitude 646.223149145953 ;
# 	:hasPhone 6912051465 .
#
# <http://api.stardog.comMiscServices#8e00984f-84c3-11ec-bef7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1683;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "(SIA COLLEGE" ;
# 	:hasName "Vegknife Online Delivery Se.." ;
# 	:hasAddress "Kanchan Co-operative Society, Sagarli, Dombivli East, Thane - 421203, South Indian College (SIA COLLEGE)" ;
# 	:hasLatitude 70.5041 ;
# 	:hasLongitude 427.699639112689 ;
# 	:hasPhone 3680899529 .
#
# <http://api.stardog.comMiscServices#8e009850-84c3-11ec-ae54-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1331;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Muhammadi Masjid" ;
# 	:hasName "M T L Masala" ;
# 	:hasAddress "Tain Villa , Shop No 5, Puja Nagar, Naya Nagar-Mira Road, Thane - 401107, Muhammadi Masjid" ;
# 	:hasLatitude 29.5546 ;
# 	:hasLongitude 228.3578714123 ;
# 	:hasPhone 8722669243 .
#
# <http://api.stardog.comMiscServices#8e00bf60-84c3-11ec-90e2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    504;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400053, Opp.Walawalkar Garden" ;
# 	:hasName "9to9 Mart" ;
# 	:hasAddress "Green Park Society, Shop D 13, Off New Link Road, Andheri West, Mumbai - 400053, Opp.Walawalkar Garden" ;
# 	:hasLatitude 20.3298 ;
# 	:hasLongitude 263.144017546438 ;
# 	:hasPhone 9331251243 .
#
# <http://api.stardog.comMiscServices#8e00bf61-84c3-11ec-9639-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    935;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400703, Near Abhudaya Bank Marg" ;
# 	:hasName "Gala Traders" ;
# 	:hasAddress "Shop No 4, Gagangiri Building,  Plot No 47, Vashi Sector 17, Navi Mumbai - 400703, Near Abhudaya Bank Marg" ;
# 	:hasLatitude 81.1692 ;
# 	:hasLongitude 587.635348201729 ;
# 	:hasPhone 7638831494 .
#
# <http://api.stardog.comMiscServices#8e00bf62-84c3-11ec-a29f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1920;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Jay Sadguru Traders" ;
# 	:hasAddress "Nalasopara East, Palghar - 401209, Near Station" ;
# 	:hasLatitude 43.0412 ;
# 	:hasLongitude 94.4559999043122 ;
# 	:hasPhone 1558677260 .
#
# <http://api.stardog.comMiscServices#8e00bf63-84c3-11ec-a199-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1939;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Suresh Stores" ;
# 	:hasAddress "Shop No.24, Ground Floor.   Galaxy Complex Sell Building, J W Road, Parel, Mumbai - 400012" ;
# 	:hasLatitude 37.148 ;
# 	:hasLongitude 726.679586223327 ;
# 	:hasPhone 2340115125 .
#
# <http://api.stardog.comMiscServices#8e00bf64-84c3-11ec-bd44-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1573;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Apka Super Market" ;
# 	:hasAddress "Sunil Nagar , Tukaram Nagar, Nandivali Road, Dombivli East, Thane - 421201, Near Nandivali Nala" ;
# 	:hasLatitude 14.4813 ;
# 	:hasLongitude 643.81261903327 ;
# 	:hasPhone 7888486072 .
#
# <http://api.stardog.comMiscServices#8e00bf65-84c3-11ec-bd3f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    917;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "School, Virat Nagar" ;
# 	:hasName "Nakoda Super Market" ;
# 	:hasAddress "DEV Krupa Buildng, Shop No 1, 2&3, Virar West, Palghar - 401303, Opposite Vidyavihar School, Virat Nagar" ;
# 	:hasLatitude 41.5888 ;
# 	:hasLongitude 561.855545383878 ;
# 	:hasPhone 4771705785 .
#
# <http://api.stardog.comMiscServices#8e00bf66-84c3-11ec-b393-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1697;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400033, Near Abhyudaya Nagar, G D Ambedkar Marg" ;
# 	:hasName "Niti General Stores" ;
# 	:hasAddress "37 / 2602  G D Ambe Kar, G D Ambekar Marg, Kala Chowki, Mumbai - 400033, Near Abhyudaya Nagar, G D Ambedkar Marg" ;
# 	:hasLatitude 68.7826 ;
# 	:hasLongitude 873.044838313945 ;
# 	:hasPhone 6716538600 .
#
# <http://api.stardog.comMiscServices#8e00e67c-84c3-11ec-b393-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1407;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "mboli" ;
# 	:hasName "Here 4 U Pharmacy" ;
# 	:hasAddress "Shop No 5 Dlh Dream Tower Building, Jai Bhavani Mata Road, Andheri West, Mumbai - 400058, Amboli" ;
# 	:hasLatitude 1.3029 ;
# 	:hasLongitude 626.657671877183 ;
# 	:hasPhone 9701568705 .
#
# <http://api.stardog.comMiscServices#8e00e67d-84c3-11ec-b6c4-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1941;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "(SIA COLLEGE" ;
# 	:hasName "Vegknife Online Delivery Se.." ;
# 	:hasAddress "Kanchan Co-operative Society, Sagarli, Dombivli East, Thane - 421203, South Indian College (SIA COLLEGE)" ;
# 	:hasLatitude 48.9534 ;
# 	:hasLongitude 367.614169488661 ;
# 	:hasPhone 3038184576 .
#
# <http://api.stardog.comMiscServices#8e00e67e-84c3-11ec-a747-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1724;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Muhammadi Masjid" ;
# 	:hasName "M T L Masala" ;
# 	:hasAddress "Tain Villa , Shop No 5, Puja Nagar, Naya Nagar-Mira Road, Thane - 401107, Muhammadi Masjid" ;
# 	:hasLatitude 49.5496 ;
# 	:hasLongitude 642.599649610929 ;
# 	:hasPhone 6556268525 .
#
# <http://api.stardog.comMiscServices#8e00e67f-84c3-11ec-9dc8-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1800;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400053, Opp.Walawalkar Garden" ;
# 	:hasName "9to9 Mart" ;
# 	:hasAddress "Green Park Society, Shop D 13, Off New Link Road, Andheri West, Mumbai - 400053, Opp.Walawalkar Garden" ;
# 	:hasLatitude 15.8566 ;
# 	:hasLongitude 832.595851854421 ;
# 	:hasPhone 7571506559 .
#
# <http://api.stardog.comMiscServices#8e00e680-84c3-11ec-abc5-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1423;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400703, Near Abhudaya Bank Marg" ;
# 	:hasName "Gala Traders" ;
# 	:hasAddress "Shop No 4, Gagangiri Building,  Plot No 47, Vashi Sector 17, Navi Mumbai - 400703, Near Abhudaya Bank Marg" ;
# 	:hasLatitude 63.989 ;
# 	:hasLongitude 47.4706535460427 ;
# 	:hasPhone 2725923989 .
#
# <http://api.stardog.comMiscServices#8e00e681-84c3-11ec-a1a9-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    910;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "" ;
# 	:hasName "Jay Sadguru Traders" ;
# 	:hasAddress "Nalasopara East, Palghar - 401209, Near Station" ;
# 	:hasLatitude 17.8383 ;
# 	:hasLongitude 199.838528060354 ;
# 	:hasPhone 8871448750 .
#
# <http://api.stardog.comMiscServices#8e00e682-84c3-11ec-bd2c-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1447;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "iety" ;
# 	:hasName "Thane Super Market" ;
# 	:hasAddress "Prayag Tirth, Veer Savarkar Marg, Naupada-thane West, Thane - 400602, Opposite Lokmanya Society" ;
# 	:hasLatitude 81.7558 ;
# 	:hasLongitude 443.079975782894 ;
# 	:hasPhone 8400658906 .
#
# <http://api.stardog.comMiscServices#8e00e683-84c3-11ec-bed7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1490;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "aupada" ;
# 	:hasName "Savla Dry Fruits" ;
# 	:hasAddress "Shradha Bhavan, Station Road, Thane West, Thane - 400601, Near Vishnunagar Ghantali Chowk Naupada" ;
# 	:hasLatitude 81.8481 ;
# 	:hasLongitude 705.752700218 ;
# 	:hasPhone 6804993235 .
#
# <http://api.stardog.comMiscServices#8e010d9b-84c3-11ec-ab36-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1277;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Opposite Parwana Tower" ;
# 	:hasName "Natures Bazzaar" ;
# 	:hasAddress "Shop No 1,Khokar Compound, Borivali West, Ram Nagar-Borivali West, Mumbai - 400092, Opposite Parwana Tower" ;
# 	:hasLatitude 69.3031 ;
# 	:hasLongitude 472.376807010733 ;
# 	:hasPhone 9009669853 .
#
# <http://api.stardog.comMiscServices#8e010d9c-84c3-11ec-96f3-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1127;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "T Road & G V Scheme No 2" ;
# 	:hasName "Sahakar Dhanya Bhandar" ;
# 	:hasAddress "Shop No 3 ,, Poorva Megh Chs, Mulund East, Mumbai - 400081, Junction Of L.T Road & G V Scheme No 2" ;
# 	:hasLatitude 76.7893 ;
# 	:hasLongitude 287.533402093686 ;
# 	:hasPhone 2646008803 .
#
# <http://api.stardog.comMiscServices#8e01349f-84c3-11ec-85f7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1449;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Danda Road, Khar West, Mumbai - 400052, Near 1st & 17th Road Corner" ;
# 	:hasName "Neelam Foodland" ;
# 	:hasAddress "3,5,6,7 Tanna Kutir, Plot No 540, C D Marg, Khar Danda Road, Khar West, Mumbai - 400052, Near 1st & 17th Road Corner" ;
# 	:hasLatitude 20.1364 ;
# 	:hasLongitude 151.030378765427 ;
# 	:hasPhone 1257113964 .
#
# <http://api.stardog.comMiscServices#8e0134a0-84c3-11ec-bb0b-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    907;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "to Hari Om Hotel" ;
# 	:hasName "Jain Traders" ;
# 	:hasAddress "Shop No 10, Parshava Kunj Building, Mathurdas Road, Kandivali West, Mumbai - 400067, Next to Hari Om Hotel" ;
# 	:hasLatitude 99.8751 ;
# 	:hasLongitude 413.793900399469 ;
# 	:hasPhone 4460702673 .
#
# <http://api.stardog.comMiscServices#8e0134a1-84c3-11ec-acfb-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1975;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Mumbai - 400083" ;
# 	:hasName "Manilal Traders" ;
# 	:hasAddress "Shop No.1, Opposite Building No.8, Tagore Nagar, Station Road, Vikhroli East, Mumbai - 400083" ;
# 	:hasLatitude 61.469 ;
# 	:hasLongitude 215.930760721676 ;
# 	:hasPhone 7459191568 .
#
# <http://api.stardog.comMiscServices#8e0134a2-84c3-11ec-8b00-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    863;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Mumbai - 400102, Opposite Three Star Bakery,Near Mahatma Gandhi School" ;
# 	:hasName "Shree Ganesh Stores" ;
# 	:hasAddress "Shop No 5, Ismail Kureshi Compound, New Link Road, Behram Baug-Jogeshwari West, Mumbai - 400102, Opposite Three Star Bakery,Near Mahatma Gandhi School" ;
# 	:hasLatitude 36.0855 ;
# 	:hasLongitude 672.192250029184 ;
# 	:hasPhone 5151080510 .
#
# <http://api.stardog.comMiscServices#8e0134a3-84c3-11ec-8b0b-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1982;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400018, Wellcare Pharmacy & More" ;
# 	:hasName "Mumbai Mart" ;
# 	:hasAddress "Shop No 12 Akansha Heights Opp Sai Service Station Gandhi Nagar, D S Road, Worli, Mumbai - 400018, Wellcare Pharmacy & More" ;
# 	:hasLatitude 26.9604 ;
# 	:hasLongitude 329.3194178259 ;
# 	:hasPhone 9595853784 .
#
# <http://api.stardog.comMiscServices#8e0134a4-84c3-11ec-8272-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    624;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Sheetal Baug Bus Stop" ;
# 	:hasName "Monarch Dry Fruit" ;
# 	:hasAddress "Shop No. 48-50, Surya Darshan Building, Walkeshwar Road, Walkeshwar, Mumbai - 400006, Opposite Sheetal Baug Bus Stop" ;
# 	:hasLatitude 42.1902 ;
# 	:hasLongitude 954.606159939431 ;
# 	:hasPhone 6375156464 .
#
# <http://api.stardog.comMiscServices#8e0134a5-84c3-11ec-9548-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1457;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Mumbai - 400083" ;
# 	:hasName "Manilal Traders" ;
# 	:hasAddress "Shop No.1, Opposite Building No.8, Tagore Nagar, Station Road, Vikhroli East, Mumbai - 400083" ;
# 	:hasLatitude 62.255 ;
# 	:hasLongitude 794.172950671054 ;
# 	:hasPhone 1430477609 .
#
# <http://api.stardog.comMiscServices#8e015bac-84c3-11ec-bf25-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    840;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Mumbai - 400102, Opposite Three Star Bakery,Near Mahatma Gandhi School" ;
# 	:hasName "Shree Ganesh Stores" ;
# 	:hasAddress "Shop No 5, Ismail Kureshi Compound, New Link Road, Behram Baug-Jogeshwari West, Mumbai - 400102, Opposite Three Star Bakery,Near Mahatma Gandhi School" ;
# 	:hasLatitude 92.1918 ;
# 	:hasLongitude 457.706413115375 ;
# 	:hasPhone 3657607717 .
#
# <http://api.stardog.comMiscServices#8e015bad-84c3-11ec-873d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1786;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "400018, Wellcare Pharmacy & More" ;
# 	:hasName "Mumbai Mart" ;
# 	:hasAddress "Shop No 12 Akansha Heights Opp Sai Service Station Gandhi Nagar, D S Road, Worli, Mumbai - 400018, Wellcare Pharmacy & More" ;
# 	:hasLatitude 97.0357 ;
# 	:hasLongitude 994.822835898958 ;
# 	:hasPhone 4910670432 .
#
# <http://api.stardog.comMiscServices#8e015bae-84c3-11ec-8889-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    623;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Mumbai" ;
# 	:hasLandmark "Sheetal Baug Bus Stop" ;
# 	:hasName "Monarch Dry Fruit" ;
# 	:hasAddress "Shop No. 48-50, Surya Darshan Building, Walkeshwar Road, Walkeshwar, Mumbai - 400006, Opposite Sheetal Baug Bus Stop" ;
# 	:hasLatitude 88.3027 ;
# 	:hasLongitude 267.612844356336 ;
# 	:hasPhone 6163995601 .
#
# <http://api.stardog.comMiscServices#8e015baf-84c3-11ec-8625-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1675;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "FH Block" ;
# 	:hasName "Delite Retail" ;
# 	:hasAddress "Shop No-23, Shoping Park Mall, Shalimar Bagh, Delhi - 110088, Near Indian Petrol Pump and BFH Block" ;
# 	:hasLatitude 58.9299 ;
# 	:hasLongitude 305.684084887616 ;
# 	:hasPhone 2191042038 .
#
# <http://api.stardog.comMiscServices#8e015bb0-84c3-11ec-90c3-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    784;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Chakki 365" ;
# 	:hasAddress "B - 27/11, Gali No. 7, Shaheen Bagh-Jamia Nagar, Delhi - 110025" ;
# 	:hasLatitude 73.7784 ;
# 	:hasLongitude 123.781034373678 ;
# 	:hasPhone 4840115524 .
#
# <http://api.stardog.comMiscServices#8e015bb1-84c3-11ec-a7dc-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1127;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Zevarr Mahal" ;
# 	:hasName "Sumer Chand Tara Chand" ;
# 	:hasAddress "Shop No-68/3, Sadar Bazaar, Basai Road, Gurgaon - 122001, Near Zevar Mahal" ;
# 	:hasLatitude 94.3112 ;
# 	:hasLongitude 163.861391949467 ;
# 	:hasPhone 1020691501 .
#
# <http://api.stardog.comMiscServices#8e015bb2-84c3-11ec-9db7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1143;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "7 Thirty Mart" ;
# 	:hasAddress "144, Avtar Enclave, Paschim Vihar, Delhi - 110063, Near Multan Nagar Red Light" ;
# 	:hasLatitude 99.6826 ;
# 	:hasLongitude 739.063770859502 ;
# 	:hasPhone 8059938436 .
#
# <http://api.stardog.comMiscServices#8e015bb3-84c3-11ec-abb2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    618;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Wonderzon.com Store to Door" ;
# 	:hasAddress "122,Antriksh Appartment, Vikaspuri, Delhi - 110018" ;
# 	:hasLatitude 15.7536 ;
# 	:hasLongitude 584.941325825639 ;
# 	:hasPhone 2424493455 .
#
# <http://api.stardog.comMiscServices#8e015bb4-84c3-11ec-aaa6-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1679;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Institutemrudpur" ;
# 	:hasName "Bg Supermart" ;
# 	:hasAddress "90G, Zamrudpur-Greater Kailash 1, Delhi - 110048, Nr Skin Institute,Jamrudpur" ;
# 	:hasLatitude 90.7279 ;
# 	:hasLongitude 460.518467822112 ;
# 	:hasPhone 7534274638 .
#
# <http://api.stardog.comMiscServices#8e015bb5-84c3-11ec-8e77-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1483;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Jain Confectionery & Import.." ;
# 	:hasAddress "Shop Number 266, INA Market, Delhi - 110022, Opposite Delhi Hart" ;
# 	:hasLatitude 62.4119 ;
# 	:hasLongitude 591.712892404757 ;
# 	:hasPhone 7640334889 .
#
# <http://api.stardog.comMiscServices#8e01a9f8-84c3-11ec-899f-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1555;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Cambridge School" ;
# 	:hasName "Discount Bazaar" ;
# 	:hasAddress "440 Niti Khand 1 Indirapuram, Mangal Chowk Road, Indirapuram, Ghaziabad - 201014, Opposite Cambridge School" ;
# 	:hasLatitude 12.898 ;
# 	:hasLongitude 206.89358713571 ;
# 	:hasPhone 7899528559 .
#
# <http://api.stardog.comMiscServices#8e01a9f9-84c3-11ec-b44d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1065;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Ritirivaaj" ;
# 	:hasAddress "Metro Pillar No. 42., Shakerpur, Shakarpur, Delhi - 110092" ;
# 	:hasLatitude 65.8036 ;
# 	:hasLongitude 951.10520219896 ;
# 	:hasPhone 8074719283 .
#
# <http://api.stardog.comMiscServices#8e01a9fa-84c3-11ec-9ea0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    517;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "1, Noida - 201318" ;
# 	:hasName "J Mart" ;
# 	:hasAddress "In Front Of 14th Avenue, Gaur City Road-Gaur City 2, Gaur City 1, Noida - 201318" ;
# 	:hasLatitude 59.8894 ;
# 	:hasLongitude 262.121503823437 ;
# 	:hasPhone 1910614869 .
#
# <http://api.stardog.comMiscServices#8e01a9fb-84c3-11ec-9f19-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1245;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Delhi - 110075" ;
# 	:hasName "The Vital Mart" ;
# 	:hasAddress "G-1,2 Pankaj Arcade Plot No.5, Pocket-4, Dwarka Sector 11, Delhi - 110075" ;
# 	:hasLatitude 15.8384 ;
# 	:hasLongitude 939.650463522412 ;
# 	:hasPhone 3483667370 .
#
# <http://api.stardog.comMiscServices#8e01a9fc-84c3-11ec-803d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    636;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Shahdara Metro Station" ;
# 	:hasName "Delhyver Food Retail Pvt. L.." ;
# 	:hasAddress "G-41, Vikas Cine Mall, G.T Road Shahdara, Shahdara, Delhi - 110032, Near Shahdara Metro Station" ;
# 	:hasLatitude 92.1657 ;
# 	:hasLongitude 791.923256474547 ;
# 	:hasPhone 5801428764 .
#
# <http://api.stardog.comMiscServices#8e01a9fd-84c3-11ec-85cf-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1331;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Saral Super Mart (Grocery V.." ;
# 	:hasAddress "CG-05,06, Unitech Arcadia, Sector -49, South City 2, Gurgaon - 122018" ;
# 	:hasLatitude 39.219 ;
# 	:hasLongitude 419.928976916708 ;
# 	:hasPhone 9830422007 .
#
# <http://api.stardog.comMiscServices#8e01d0df-84c3-11ec-bec0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    955;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Daily Needs" ;
# 	:hasAddress "45,Corner Market, Malviya Nagar, Delhi - 110017" ;
# 	:hasLatitude 42.788 ;
# 	:hasLongitude 751.323152682744 ;
# 	:hasPhone 7537985711 .
#
# <http://api.stardog.comMiscServices#8e01d0e0-84c3-11ec-a3ee-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1908;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Jain Sweet Wali Gali and Maruti Service Station" ;
# 	:hasName "Jaideep Mega Store" ;
# 	:hasAddress "Shop-154, Mangolpur Kalan, Rohini Sector 2, Delhi - 110085, Opp. - Pocket 4, Near Jain Sweet Wali Gali and Maruti Service Station" ;
# 	:hasLatitude 91.1867 ;
# 	:hasLongitude 663.182512274943 ;
# 	:hasPhone 9586033711 .
#
# <http://api.stardog.comMiscServices#8e01d0e1-84c3-11ec-80d4-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1497;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Jai Maa Kamakhya Kirana Sto.." ;
# 	:hasAddress "GARHI CHAUKHANDI, Noida Sector 68, Noida - 201307, Near Yadav Mobile Wali Gali" ;
# 	:hasLatitude 79.4198 ;
# 	:hasLongitude 61.2620551837608 ;
# 	:hasPhone 2812117778 .
#
# <http://api.stardog.comMiscServices#8e01f84a-84c3-11ec-9c3a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    799;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Lala Ki Dukaan" ;
# 	:hasAddress "Shop No 1, Crossing Republik, Ghaziabad - 201016, Near Sushant Aquapolis" ;
# 	:hasLatitude 58.0929 ;
# 	:hasLongitude 654.868037789129 ;
# 	:hasPhone 1086683363 .
#
# <http://api.stardog.comMiscServices#8e01f84b-84c3-11ec-a53e-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    867;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Modern Bazaar" ;
# 	:hasAddress "15, Community Center, New Friends Colony, Delhi - 110025, Behind Surya Sofitel Hotel" ;
# 	:hasLatitude 32.8964 ;
# 	:hasLongitude 10.4362532729283 ;
# 	:hasPhone 8348576191 .
#
# <http://api.stardog.comMiscServices#8e01f84c-84c3-11ec-b651-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1517;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "aldiram" ;
# 	:hasName "Home Store 12x7" ;
# 	:hasAddress "Gf 23, GF-23, Crossing Republik, Noida Extension,, Crossing Republik, Ghaziabad - 201016, Haldiram" ;
# 	:hasLatitude 66.4802 ;
# 	:hasLongitude 621.106644510292 ;
# 	:hasPhone 8893751782 .
#
# <http://api.stardog.comMiscServices#8e01f84d-84c3-11ec-9cec-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1799;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Club, Sector 28" ;
# 	:hasName "SUPER BAKERY GALLERIA MKT" ;
# 	:hasAddress "SG-29-30, Galleria Market, DLF City Phase 4, Gurgaon - 122002, Opposite DLF Club, Sector 28" ;
# 	:hasLatitude 35.1651 ;
# 	:hasLongitude 716.247520991601 ;
# 	:hasPhone 3414549448 .
#
# <http://api.stardog.comMiscServices#8e01f84e-84c3-11ec-b333-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    527;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Delhi - 110075" ;
# 	:hasName "The Vital Mart" ;
# 	:hasAddress "G-1,2 Pankaj Arcade Plot No.5, Pocket-4, Dwarka Sector 11, Delhi - 110075" ;
# 	:hasLatitude 15.7911 ;
# 	:hasLongitude 168.531660339795 ;
# 	:hasPhone 7296653340 .
#
# <http://api.stardog.comMiscServices#8e01f84f-84c3-11ec-a210-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    846;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Shahdara Metro Station" ;
# 	:hasName "Delhyver Food Retail Pvt. L.." ;
# 	:hasAddress "G-41, Vikas Cine Mall, G.T Road Shahdara, Shahdara, Delhi - 110032, Near Shahdara Metro Station" ;
# 	:hasLatitude 11.0579 ;
# 	:hasLongitude 563.854750827886 ;
# 	:hasPhone 2690396884 .
#
# <http://api.stardog.comMiscServices#8e01f850-84c3-11ec-93f0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    680;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Saral Super Mart (Grocery V.." ;
# 	:hasAddress "CG-05,06, Unitech Arcadia, Sector -49, South City 2, Gurgaon - 122018" ;
# 	:hasLatitude 13.1407 ;
# 	:hasLongitude 775.978810270317 ;
# 	:hasPhone 8479696205 .
#
# <http://api.stardog.comMiscServices#8e01f851-84c3-11ec-9fd2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1649;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Daily Needs" ;
# 	:hasAddress "45,Corner Market, Malviya Nagar, Delhi - 110017" ;
# 	:hasLatitude 24.8967 ;
# 	:hasLongitude 864.395892596804 ;
# 	:hasPhone 3061761638 .
#
# <http://api.stardog.comMiscServices#8e01f852-84c3-11ec-a42b-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    893;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Jain Sweet Wali Gali and Maruti Service Station" ;
# 	:hasName "Jaideep Mega Store" ;
# 	:hasAddress "Shop-154, Mangolpur Kalan, Rohini Sector 2, Delhi - 110085, Opp. - Pocket 4, Near Jain Sweet Wali Gali and Maruti Service Station" ;
# 	:hasLatitude 61.7007 ;
# 	:hasLongitude 248.669677763246 ;
# 	:hasPhone 5970271540 .
#
# <http://api.stardog.comMiscServices#8e01f853-84c3-11ec-845a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    597;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Jai Maa Kamakhya Kirana Sto.." ;
# 	:hasAddress "GARHI CHAUKHANDI, Noida Sector 68, Noida - 201307, Near Yadav Mobile Wali Gali" ;
# 	:hasLatitude 68.71 ;
# 	:hasLongitude 885.158075368963 ;
# 	:hasPhone 2485428651 .
#
# <http://api.stardog.comMiscServices#8e021fc1-84c3-11ec-b42a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    952;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Lala Ki Dukaan" ;
# 	:hasAddress "Shop No 1, Crossing Republik, Ghaziabad - 201016, Near Sushant Aquapolis" ;
# 	:hasLatitude 32.8084 ;
# 	:hasLongitude 924.615859170444 ;
# 	:hasPhone 8816598379 .
#
# <http://api.stardog.comMiscServices#8e021fc2-84c3-11ec-aa04-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1448;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Modern Bazaar" ;
# 	:hasAddress "15, Community Center, New Friends Colony, Delhi - 110025, Behind Surya Sofitel Hotel" ;
# 	:hasLatitude 1.6733 ;
# 	:hasLongitude 876.194638782181 ;
# 	:hasPhone 4550666594 .
#
# <http://api.stardog.comMiscServices#8e021fc3-84c3-11ec-976a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    508;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "aldiram" ;
# 	:hasName "Home Store 12x7" ;
# 	:hasAddress "Gf 23, GF-23, Crossing Republik, Noida Extension,, Crossing Republik, Ghaziabad - 201016, Haldiram" ;
# 	:hasLatitude 35.564 ;
# 	:hasLongitude 273.258962319233 ;
# 	:hasPhone 7939753042 .
#
# <http://api.stardog.comMiscServices#8e021fc4-84c3-11ec-a76d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    798;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Club, Sector 28" ;
# 	:hasName "SUPER BAKERY GALLERIA MKT" ;
# 	:hasAddress "SG-29-30, Galleria Market, DLF City Phase 4, Gurgaon - 122002, Opposite DLF Club, Sector 28" ;
# 	:hasLatitude 10.2761 ;
# 	:hasLongitude 605.326981167309 ;
# 	:hasPhone 2316425579 .
#
# <http://api.stardog.comMiscServices#8e021fc5-84c3-11ec-b047-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1575;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Near Metro Station" ;
# 	:hasName "Saradhya Organics" ;
# 	:hasAddress "Shop No. 1, Plot No. 2, Golf Avenue, Noida Sector 75, Noida - 201304, Near Metro Station" ;
# 	:hasLatitude 7.5177 ;
# 	:hasLongitude 735.439953976311 ;
# 	:hasPhone 4332446728 .
#
# <http://api.stardog.comMiscServices#8e024643-84c3-11ec-841b-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1709;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Chadda Bhawan" ;
# 	:hasName "Aggarwal Traders" ;
# 	:hasAddress "Shop Number  7259/3, Shakti Nagar, Delhi - 110007, Opp Chadda Bhawan" ;
# 	:hasLatitude 29.2415 ;
# 	:hasLongitude 968.691965914331 ;
# 	:hasPhone 2064131629 .
#
# <http://api.stardog.comMiscServices#8e024644-84c3-11ec-a4e9-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1612;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Manish Agencies (Dough&Crea.." ;
# 	:hasAddress "D-112, Vikaspuri road, Vikaspuri, Delhi - 110018, Arya Samaj Mandir" ;
# 	:hasLatitude 37.9507 ;
# 	:hasLongitude 11.9724482065067 ;
# 	:hasPhone 7467523792 .
#
# <http://api.stardog.comMiscServices#8e024645-84c3-11ec-941c-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1697;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "ound Floor" ;
# 	:hasName "Madhav Store" ;
# 	:hasAddress "Madhav Store, Shakti Khand 3 Indirapuram Ghaziabad, Indirapuram, Ghaziabad - 201014, 253 Ground Floor" ;
# 	:hasLatitude 96.3994 ;
# 	:hasLongitude 845.277319080196 ;
# 	:hasPhone 4875692628 .
#
# <http://api.stardog.comMiscServices#8e024646-84c3-11ec-9065-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1380;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Modern Bazaar" ;
# 	:hasAddress "47, North Avenue, Club Road, Punjabi Bagh, Delhi - 110026" ;
# 	:hasLatitude 54.1544 ;
# 	:hasLongitude 861.592110362835 ;
# 	:hasPhone 3716236122 .
#
# <http://api.stardog.comMiscServices#8e024647-84c3-11ec-9135-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    711;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Pillar No-365" ;
# 	:hasName "Essential Grocery & More" ;
# 	:hasAddress "Gd-28 Ground Floor, Pitampura, Delhi - 110088, Pillar No-365" ;
# 	:hasLatitude 64.4956 ;
# 	:hasLongitude 667.50117985066 ;
# 	:hasPhone 8743448108 .
#
# <http://api.stardog.comMiscServices#8e024648-84c3-11ec-abdd-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1593;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Baramdataurant" ;
# 	:hasName "Karachy Bakery And Organic .." ;
# 	:hasAddress "Plot No.-4, Khari Market, Noida Sector 141, Noida - 201305, Near Baramda Restaurant" ;
# 	:hasLatitude 35.2039 ;
# 	:hasLongitude 267.660959274508 ;
# 	:hasPhone 5177842932 .
#
# <http://api.stardog.comMiscServices#8e024649-84c3-11ec-a1b7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    517;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Smart Mart" ;
# 	:hasAddress "G-2&3, Main Dwarka Expressway, Gurgaon Sector 99, Gurgaon - 122006, Ocus Medley" ;
# 	:hasLatitude 32.9508 ;
# 	:hasLongitude 40.8708514878526 ;
# 	:hasPhone 8400112877 .
#
# <http://api.stardog.comMiscServices#8e02464a-84c3-11ec-81e2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1819;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Number 368" ;
# 	:hasName "Sardaran Di Hatti" ;
# 	:hasAddress "FD 8, Pitampura, Delhi - 110034, Near Metro Station Pitampura & Opposite Metro Pillar Number 368" ;
# 	:hasLatitude 93.4611 ;
# 	:hasLongitude 117.033554823138 ;
# 	:hasPhone 1577646053 .
#
# <http://api.stardog.comMiscServices#8e02464b-84c3-11ec-8049-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    943;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Store To Door" ;
# 	:hasAddress "Shop No 210, 2nd Floor, Gaur City 1, Noida - 201318, Aarza Square 2" ;
# 	:hasLatitude 72.251 ;
# 	:hasLongitude 602.532367338426 ;
# 	:hasPhone 6738852468 .
#
# <http://api.stardog.comMiscServices#8e02464c-84c3-11ec-80ab-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1939;
# 	:hasService "Grocery Stores" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Near Metro Station" ;
# 	:hasName "Saradhya Organics" ;
# 	:hasAddress "Shop No. 1, Plot No. 2, Golf Avenue, Noida Sector 75, Noida - 201304, Near Metro Station" ;
# 	:hasLatitude 83.7779 ;
# 	:hasLongitude 154.570232494734 ;
# 	:hasPhone 2191656830 .
#
# ...
# 	:hasLatitude 68.89 ;
# 	:hasLongitude 756.250665872358 ;
# 	:hasPhone 7970273075 .
#
# <http://api.stardog.comMiscServices#8e0ad1a0-84c3-11ec-acfa-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    565;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Winene Shop" ;
# 	:hasName "Amit Electrical" ;
# 	:hasAddress "Shop No 1, Main Road, Noida Sector 77, Noida - 201304, Near Wine Shop" ;
# 	:hasLatitude 23.0445 ;
# 	:hasLongitude 456.647966173478 ;
# 	:hasPhone 5627753916 .
#
# <http://api.stardog.comMiscServices#8e0ad1a1-84c3-11ec-824c-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1558;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Patparganj 110092" ;
# 	:hasName "Rahul Electrician" ;
# 	:hasAddress "Shop No 55-56, Patparganj, Delhi - 110092" ;
# 	:hasLatitude 66.2033 ;
# 	:hasLongitude 98.9347429713234 ;
# 	:hasPhone 3434229105 .
#
# <http://api.stardog.comMiscServices#8e0ad1a2-84c3-11ec-94f6-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1454;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Police Chowki" ;
# 	:hasName "Bunty Electrician Contracto.." ;
# 	:hasAddress "W-167/24, Harijan Colony, Tilak Nagar, Delhi - 110018, Near Police Chowki" ;
# 	:hasLatitude 33.228 ;
# 	:hasLongitude 479.186991113238 ;
# 	:hasPhone 1688155428 .
#
# <http://api.stardog.comMiscServices#8e0ad1a3-84c3-11ec-abc0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1147;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Oldd Thana" ;
# 	:hasName "Rajeev Sharma Industrial El.." ;
# 	:hasAddress "F-81, Gali-81, Uttam Nagar, Delhi - 110059, Near Bindapur Old Thana" ;
# 	:hasLatitude 92.451 ;
# 	:hasLongitude 118.70271305088 ;
# 	:hasPhone 6166039887 .
#
# <http://api.stardog.comMiscServices#8e0ad1a4-84c3-11ec-a675-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1708;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Jaiswal Electrical" ;
# 	:hasAddress "Shop No. G -81, West Patel Nagar, Delhi - 110008, Near Chatri Park" ;
# 	:hasLatitude 96.9182 ;
# 	:hasLongitude 545.892001478933 ;
# 	:hasPhone 2315933990 .
#
# <http://api.stardog.comMiscServices#8e0ad1a5-84c3-11ec-9da2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1348;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Ajay Electrical And Civil W.." ;
# 	:hasAddress "Rz E1/A, Mahavir Enclave, Delhi - 110045, Near Fit I'M Gym N Spa" ;
# 	:hasLatitude 36.1619 ;
# 	:hasLongitude 463.934864732437 ;
# 	:hasPhone 7719552137 .
#
# <http://api.stardog.comMiscServices#8e0af8ad-84c3-11ec-9a76-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1800;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Ak Power Solutions" ;
# 	:hasAddress "House No. 543, Shiv Park, Khora Colony, Noida - 201309, Opposite Sunrise Public School" ;
# 	:hasLatitude 75.1023 ;
# 	:hasLongitude 217.607460333966 ;
# 	:hasPhone 6607635436 .
#
# <http://api.stardog.comMiscServices#8e0af8ae-84c3-11ec-b7c5-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    873;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Sakett Metro" ;
# 	:hasName "Viraj Electricals" ;
# 	:hasAddress "Building No 50, Gali Number 1 Saidulajab, Saket, Delhi - 110017, Near Saket Metro" ;
# 	:hasLatitude 52.2324 ;
# 	:hasLongitude 193.129186867736 ;
# 	:hasPhone 3987087356 .
#
# <http://api.stardog.comMiscServices#8e0af8af-84c3-11ec-ada7-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1904;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Electrician On Call" ;
# 	:hasAddress "M-15 Lajpat Nagar 3, Lajpat Nagar 3, Delhi - 110024" ;
# 	:hasLatitude 73.8195 ;
# 	:hasLongitude 968.329988769256 ;
# 	:hasPhone 3540135615 .
#
# <http://api.stardog.comMiscServices#8e0af8b0-84c3-11ec-8208-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    929;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Public School" ;
# 	:hasName "Anil Electricals" ;
# 	:hasAddress "Plot Number  25-26,, Friends Enclave,, Shahberi, Ghaziabad - 201009, Near Modern Public School" ;
# 	:hasLatitude 30.7972 ;
# 	:hasLongitude 599.496283219196 ;
# 	:hasPhone 3087215018 .
#
# <http://api.stardog.comMiscServices#8e0af8b1-84c3-11ec-8add-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    755;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Rana Electricals" ;
# 	:hasAddress "Bani Squre, Gurgaon Sector 49, Gurgaon - 122018, Near SS Plaza" ;
# 	:hasLatitude 22.211 ;
# 	:hasLongitude 874.40100510139 ;
# 	:hasPhone 2522892675 .
#
# <http://api.stardog.comMiscServices#8e0af8b2-84c3-11ec-b0c2-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1844;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "MetroStation" ;
# 	:hasName "Sarvesh Electricion" ;
# 	:hasAddress "Plot No -210, Gali No -22, Delhi - 110078, Near Metro  Station" ;
# 	:hasLatitude 4.2413 ;
# 	:hasLongitude 620.33576273825 ;
# 	:hasPhone 1373244499 .
#
# <http://api.stardog.comMiscServices#8e0af8b3-84c3-11ec-bb0d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1536;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Shiv Mandir" ;
# 	:hasName "Dev Electricals" ;
# 	:hasAddress "28/94 Gali No 14 Nr Shiv Mandir, Vishwas Nagar-Shahdara, Delhi - 110032, Shiv Mandir" ;
# 	:hasLatitude 77.2279 ;
# 	:hasLongitude 596.205976675265 ;
# 	:hasPhone 3998929848 .
#
# <http://api.stardog.comMiscServices#8e0af8b4-84c3-11ec-99fd-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1682;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Oldd Thana" ;
# 	:hasName "Rajeev Sharma Industrial El.." ;
# 	:hasAddress "F-81, Gali-81, Uttam Nagar, Delhi - 110059, Near Bindapur Old Thana" ;
# 	:hasLatitude 52.0627 ;
# 	:hasLongitude 782.402845681645 ;
# 	:hasPhone 6655120858 .
#
# <http://api.stardog.comMiscServices#8e0af8b5-84c3-11ec-8ef5-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    849;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Jaiswal Electrical" ;
# 	:hasAddress "Shop No. G -81, West Patel Nagar, Delhi - 110008, Near Chatri Park" ;
# 	:hasLatitude 60.3567 ;
# 	:hasLongitude 411.593503435142 ;
# 	:hasPhone 3241728209 .
#
# <http://api.stardog.comMiscServices#8e0af8b6-84c3-11ec-a760-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    627;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Ajay Electrical And Civil W.." ;
# 	:hasAddress "Rz E1/A, Mahavir Enclave, Delhi - 110045, Near Fit I'M Gym N Spa" ;
# 	:hasLatitude 44.5879 ;
# 	:hasLongitude 156.214809394442 ;
# 	:hasPhone 8010869768 .
#
# <http://api.stardog.comMiscServices#8e0af8b7-84c3-11ec-acde-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1529;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Ak Power Solutions" ;
# 	:hasAddress "House No. 543, Shiv Park, Khora Colony, Noida - 201309, Opposite Sunrise Public School" ;
# 	:hasLatitude 93.3729 ;
# 	:hasLongitude 707.249867380597 ;
# 	:hasPhone 1114175571 .
#
# <http://api.stardog.comMiscServices#8e0af8b8-84c3-11ec-b202-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    933;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Sakett Metro" ;
# 	:hasName "Viraj Electricals" ;
# 	:hasAddress "Building No 50, Gali Number 1 Saidulajab, Saket, Delhi - 110017, Near Saket Metro" ;
# 	:hasLatitude 79.0363 ;
# 	:hasLongitude 694.142993190326 ;
# 	:hasPhone 5379968734 .
#
# <http://api.stardog.comMiscServices#8e0af8b9-84c3-11ec-a3ef-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1121;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Electrician On Call" ;
# 	:hasAddress "M-15 Lajpat Nagar 3, Lajpat Nagar 3, Delhi - 110024" ;
# 	:hasLatitude 97.5199 ;
# 	:hasLongitude 974.471017369069 ;
# 	:hasPhone 3144603930 .
#
# <http://api.stardog.comMiscServices#8e0af8ba-84c3-11ec-bf18-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    773;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Public School" ;
# 	:hasName "Anil Electricals" ;
# 	:hasAddress "Plot Number  25-26,, Friends Enclave,, Shahberi, Ghaziabad - 201009, Near Modern Public School" ;
# 	:hasLatitude 18.5808 ;
# 	:hasLongitude 661.572030396201 ;
# 	:hasPhone 8375905540 .
#
# <http://api.stardog.comMiscServices#8e0af8bb-84c3-11ec-a27c-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1586;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Rana Electricals" ;
# 	:hasAddress "Bani Squre, Gurgaon Sector 49, Gurgaon - 122018, Near SS Plaza" ;
# 	:hasLatitude 32.7798 ;
# 	:hasLongitude 112.918246886693 ;
# 	:hasPhone 1168656190 .
#
# <http://api.stardog.comMiscServices#8e0b1fc0-84c3-11ec-b6e1-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    850;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "MetroStation" ;
# 	:hasName "Sarvesh Electricion" ;
# 	:hasAddress "Plot No -210, Gali No -22, Delhi - 110078, Near Metro  Station" ;
# 	:hasLatitude 78.0474 ;
# 	:hasLongitude 197.4773198599 ;
# 	:hasPhone 6099149219 .
#
# <http://api.stardog.comMiscServices#8e0b1fc1-84c3-11ec-87c8-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1830;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Shiv Mandir" ;
# 	:hasName "Dev Electricals" ;
# 	:hasAddress "28/94 Gali No 14 Nr Shiv Mandir, Vishwas Nagar-Shahdara, Delhi - 110032, Shiv Mandir" ;
# 	:hasLatitude 77.8884 ;
# 	:hasLongitude 375.192314735614 ;
# 	:hasPhone 7264820453 .
#
# <http://api.stardog.comMiscServices#8e0b1fc2-84c3-11ec-aa0a-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1137;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "indirapuram 201014" ;
# 	:hasName "J K Electricals" ;
# 	:hasAddress "Shop No. 7, Main Road, Gyan Khand 4-indirapuram, Ghaziabad - 201014" ;
# 	:hasLatitude 30.9932 ;
# 	:hasLongitude 36.4315124461427 ;
# 	:hasPhone 2695081454 .
#
# <http://api.stardog.comMiscServices#8e0b1fc3-84c3-11ec-9e15-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1945;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "RampuraFlyover" ;
# 	:hasName "Shree Shyam Electrician and.." ;
# 	:hasAddress "N H 8, Gurgaon Sector 83, Gurgaon - 122004, Near Rampura Flyover" ;
# 	:hasLatitude 91.9992 ;
# 	:hasLongitude 879.012641613372 ;
# 	:hasPhone 5527849551 .
#
# <http://api.stardog.comMiscServices#8e0b1fc4-84c3-11ec-905d-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1346;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Najim Electrical" ;
# 	:hasAddress "Shop No 70, Carterpuri, Palam Vihar, Gurgaon - 122017, Near McDonald's" ;
# 	:hasLatitude 70.0361 ;
# 	:hasLongitude 726.189634413458 ;
# 	:hasPhone 8854583859 .
#
# <http://api.stardog.comMiscServices#8e0b1fc5-84c3-11ec-b922-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    718;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "110059" ;
# 	:hasName "Mehta Electricals" ;
# 	:hasAddress "Rz-74 Jain Colony Part 1, Shukar Bazar Road, Uttam Nagar West, Delhi - 110059" ;
# 	:hasLatitude 85.5736 ;
# 	:hasLongitude 428.617136902176 ;
# 	:hasPhone 2932506955 .
#
# <http://api.stardog.comMiscServices#8e0b1fc6-84c3-11ec-bbf8-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1669;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "AlenaCompany" ;
# 	:hasName "Vishnu Electrical" ;
# 	:hasAddress "Shop Number C 239, Ashok Vihar 2, Delhi - 110052, Near Auto Alena Company" ;
# 	:hasLatitude 13.5142 ;
# 	:hasLongitude 311.838286113925 ;
# 	:hasPhone 8441748450 .
#
# <http://api.stardog.comMiscServices#8e0c800f-84c3-11ec-8311-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1593;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Sector 122001" ;
# 	:hasName "Piyush Electrical" ;
# 	:hasAddress "Kailash Bhagat, 468,Silokhra, Gurgaon Sector 31, Gurgaon - 122001" ;
# 	:hasLatitude 63.2247 ;
# 	:hasLongitude 36.1627183156088 ;
# 	:hasPhone 1181542400 .
#
# <http://api.stardog.comMiscServices#8e0c8010-84c3-11ec-9cce-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1732;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Gurunanak Electricals" ;
# 	:hasAddress "Plot No. A2/42, Gupta Palace, 1st Floor 121, Rajouri Garden, Delhi - 110027" ;
# 	:hasLatitude 13.2923 ;
# 	:hasLongitude 104.921465623192 ;
# 	:hasPhone 5258269952 .
#
# <http://api.stardog.comMiscServices#8e0c8011-84c3-11ec-9808-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    513;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Indera Colony" ;
# 	:hasName "Md Sohail Electricians" ;
# 	:hasAddress "House No 4, Gurgaon Sector 52, Gurgaon - 122002, Indera Colony" ;
# 	:hasLatitude 12.9379 ;
# 	:hasLongitude 741.919193533249 ;
# 	:hasPhone 7988676363 .
#
# <http://api.stardog.comMiscServices#8e0c8012-84c3-11ec-99d0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    946;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "East 110051" ;
# 	:hasName "M S Electrical" ;
# 	:hasAddress "C-7, Street No-9, Krishna Nagar East, Delhi - 110051" ;
# 	:hasLatitude 89.7574 ;
# 	:hasLongitude 811.098071397282 ;
# 	:hasPhone 3963756706 .
#
# <http://api.stardog.comMiscServices#8e0ca66e-84c3-11ec-bd34-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1583;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Pc Electrical Works" ;
# 	:hasAddress "A-233 Sector-69, Transport Nagar, Noida Sector 69, Noida - 201307" ;
# 	:hasLatitude 21.8795 ;
# 	:hasLongitude 765.539618791081 ;
# 	:hasPhone 1124125926 .
#
# <http://api.stardog.comMiscServices#8e0ca66f-84c3-11ec-b881-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    741;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Sector 122001" ;
# 	:hasName "Piyush Electrical" ;
# 	:hasAddress "Kailash Bhagat, 468,Silokhra, Gurgaon Sector 31, Gurgaon - 122001" ;
# 	:hasLatitude 32.3297 ;
# 	:hasLongitude 944.514086819254 ;
# 	:hasPhone 7149993050 .
#
# <http://api.stardog.comMiscServices#8e0ca670-84c3-11ec-aba1-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    971;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Gurunanak Electricals" ;
# 	:hasAddress "Plot No. A2/42, Gupta Palace, 1st Floor 121, Rajouri Garden, Delhi - 110027" ;
# 	:hasLatitude 81.3685 ;
# 	:hasLongitude 830.761795048602 ;
# 	:hasPhone 1639118768 .
#
# <http://api.stardog.comMiscServices#8e0ca671-84c3-11ec-a8b0-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    532;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "Indera Colony" ;
# 	:hasName "Md Sohail Electricians" ;
# 	:hasAddress "House No 4, Gurgaon Sector 52, Gurgaon - 122002, Indera Colony" ;
# 	:hasLatitude 65.6191 ;
# 	:hasLongitude 525.991729111411 ;
# 	:hasPhone 1755583948 .
#
# <http://api.stardog.comMiscServices#8e0ca672-84c3-11ec-b27c-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1996;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "East 110051" ;
# 	:hasName "M S Electrical" ;
# 	:hasAddress "C-7, Street No-9, Krishna Nagar East, Delhi - 110051" ;
# 	:hasLatitude 72.5009 ;
# 	:hasLongitude 217.16436452698 ;
# 	:hasPhone 9282229082 .
#
# <http://api.stardog.comMiscServices#8e0ca673-84c3-11ec-a815-9828a61c799d> a <http://api.stardog.comMiscServices> ;
# 	:hasPrice    1997;
# 	:hasService "Electrician" ;
# 	:hasLocation "Delhi" ;
# 	:hasLandmark "" ;
# 	:hasName "Pc Electrical Works" ;
# 	:hasAddress "A-233 Sector-69, Transport Nagar, Noida Sector 69, Noida - 201307" ;
# 	:hasLatitude 73.5009 ;
# 	:hasLongitude 218.16436452698 ;
# 	:hasPhone 9282229083 .

# %%
connection_details = {
  'endpoint': 'http://localhost:5820',
  'username': 'admin',
  'password': 'admin'
}

database_name = 'massive_insertion_v3'

# with stardog.Admin(**connection_details) as admin:
#     if database_name in [db.name for db in admin.databases()]:
#         admin.database(database_name).drop()
#     db = admin.new_database(database_name)
    
conn = stardog.Connection(database_name, **connection_details)
conn.begin()
# Out:
# '403d4272-8a5f-4a08-b87d-f507a4f5ef8c'

# %%
# conn.add(stardog.content.File('C:/xampp/htdocs/python/dummy_dataset.ttl'))
conn.add(stardog.content.File('MiscServices.ttl'))

conn.commit()

# %%
conn.__exit__()
