# %%
import csv
import uuid
import stardog

#create a new variable called 'outfile' (could be any name), which we'll use to create a new file that we'll pass our TTL into.
outfile = open('school.ttl', 'a',encoding='latin-1')

with open('C:/Users/ekjot/Downloads/allSchoolsCombined.csv', 'r',encoding='latin-1') as read_obj:
    Reader = csv.reader(read_obj)
#ifile = open('councils-data.csv', 'rb')
#reader = csv.reader(ifile)

#create a new variable called 'outfile' (could be any name), which we'll use to create a new file that we'll pass our TTL into.
    

    #get python to loop through each row in the CSV, and ignore the first row.
    query = """
        @prefix : <http://api.stardog.com/> .
        @prefix stardog: <tag:stardog:api:> .
        @prefix owl: <http://www.w3.org/2002/07/owl#> .
        @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
        @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
        @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

        """
    rownum = 0
    for row in Reader:
        if rownum == 0:
            pass
        else:
            c = row
            prefix = "<http://api.stardog.comschool#" + str(uuid.uuid1()) + "> "
            postfix = " <http://api.stardog.comschool> ;"
            output = prefix + "a" + postfix
            output = output +"\n\t:hasschoolType    \"" + str(row[6]) + " \";\n"
            output = output + "\t:hasLocation \"" + row[1] + "\" ;\n" + "\t:hasLandmark \"" + row[3] + "\" ;\n" + "\t:hasName \"" + row[0] + "\" ;\n" + "\t:hasAddress \"" + row[2] + "\" ;\n" + "\t:hasLatitude " + str(row[5]) + " ;\n" + "\t:hasLongitude " + str(row[4]) + " ;\n" + "\t:hasPhone " + str(row[7]) + " .\n"
            print(output)
            outfile.write(output)
        rownum += 1
    outfile.close()
#ifile.close()
# Out:
# <http://api.stardog.comschool#b8e345cc-84bd-11ec-aec5-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark " Near Hasthinapuram Mosque" ;
# 	:hasName "Shikshaa Matriculation High.." ;
# 	:hasAddress "No 8, Ponniamman Koil Street, Hasthinapuram-chitlapakkam, Chennai - 600064, Near Hasthinapuram Mosque , BUS STOP" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5592102529 .
#
# <http://api.stardog.comschool#b8e345cd-84bd-11ec-8859-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Siddharth Upscale Height" ;
# 	:hasName "Narayana E Techno School" ;
# 	:hasAddress "No: 53, MS Nagar ,Porur Kundrathur  Main Road, Madhanandapuram, Chennai - 600116, Next to Siddharth Upscale Heights" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6033784005 .
#
# <http://api.stardog.comschool#b8e36c77-84bd-11ec-a03c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "SHELL PETROL BUNK" ;
# 	:hasName "NARAYANA E-TECHNO SCHOOL PA.." ;
# 	:hasAddress "NO 90 200 FEET ROAD ZAMIN PALLAVARAM, 200 FEET ROAD, Zamin Pallavaram, Chennai - 600043, SHELL PETROL BUNK" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9642415459 .
#
# <http://api.stardog.comschool#b8e36c78-84bd-11ec-9153-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Near Mega Mart" ;
# 	:hasName "Sri Venkateswara Matriculat.." ;
# 	:hasAddress "No 104 B, 1st Main Road Alwar Thirunagar Annexe, Alwarthirunagar, Chennai - 600087, Near Mega Mart" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5076301321 .
#
# <http://api.stardog.comschool#b8e36c79-84bd-11ec-923b-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Kolathur Vazhathoppu & Krishna Swimming Pool" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No: 240, B Block, 3rd Cross Street, Ponniammanmedu, Chennai - 600110, Near Kolathur Vazhathoppu & Krishna Swimming Pool, Swamy Ramalinga Colony, Kolathur" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5002853538 .
#
# <http://api.stardog.comschool#b8e36c7a-84bd-11ec-a260-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Indian Bank" ;
# 	:hasName "Angel School" ;
# 	:hasAddress "NO 11&12, E B COLONY,LAKSHMIPURAM, Thirunindravur, Chennai - 602024, Near Indian Bank" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4106842383 .
#
# <http://api.stardog.comschool#b8e36c7b-84bd-11ec-9676-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Padappai, Chennai - 601301, Salamangalam" ;
# 	:hasName "Velammal Vidhyashram" ;
# 	:hasAddress "No 3, Walajabad Main Road, Padappai, Chennai - 601301, Salamangalam" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8982784226 .
#
# <http://api.stardog.comschool#b8e36c7c-84bd-11ec-ae4b-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Opposite Murugan Temple" ;
# 	:hasName "Narayana E - Techno School" ;
# 	:hasAddress "No 9, Meenakshi Street Karthikeyan Nagar, Maduravoyal, Chennai - 600095, Opposite Murugan Temple" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 3682256320 .
#
# <http://api.stardog.comschool#b8e36c7d-84bd-11ec-8336-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Near Hastinapuram Mosque" ;
# 	:hasName "Shikshaa Public School CBSE" ;
# 	:hasAddress "No: 8, Ponniamman Koil Street, Hasthinapuram-chitlapakkam, Chennai - 600064, Near Hastinapuram Mosque" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2460775937 .
#
# <http://api.stardog.comschool#b8e36c7e-84bd-11ec-a6a4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Petrol Bunk & Soka Ikeda Womens College" ;
# 	:hasName "Satheesh Balaji Matric. Hr..." ;
# 	:hasAddress "No 1, College Road, Madhanakuppam, Kolathur, Chennai - 600099, Near Bharat Petrol Bunk & Soka Ikeda Womens College" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8182453243 .
#
# <http://api.stardog.comschool#b8e36c7f-84bd-11ec-b202-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Temple" ;
# 	:hasName "Narayana E Techno School" ;
# 	:hasAddress "No96 8th Block, 191st Street Muthamiz Nagar, Kodungaiyur, Chennai - 600118, Near Bhavani Amman Temple" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2349779181 .
#
# <http://api.stardog.comschool#b8e36c80-84bd-11ec-afd7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Mosque" ;
# 	:hasName "Aadhithya International Pub.." ;
# 	:hasAddress "No 6, 2nd Main Road Royal Garden, Goparasanallur Village, Kattupakkam, Chennai - 600056, Near Mosque" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 7948644177 .
#
# <http://api.stardog.comschool#b8e36c81-84bd-11ec-b68c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "MIT Play Ground" ;
# 	:hasName "S C S Matric Higher Seconda.." ;
# 	:hasAddress "No 30, Ramachandra Road ,Nehru Nagar, Chromepet, Chennai - 600044, Near MIT Play Ground" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 3466346751 .
#
# <http://api.stardog.comschool#b8e36c82-84bd-11ec-850a-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Korattur" ;
# 	:hasName "Abs Global Smart School" ;
# 	:hasAddress "No 1, Vedhachalam Garaden, Korattur, Chennai - 600050" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9987125891 .
#
# <http://api.stardog.comschool#b8e36c83-84bd-11ec-9bc2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Chennai - 600053, Aarthi Sweets" ;
# 	:hasName "PNET School" ;
# 	:hasAddress "No.616/2, Murugappa Reddy Street, Ambattur Ot Bus Terminus-Ambattur, Chennai - 600053, Aarthi Sweets" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9940483429 .
#
# <http://api.stardog.comschool#b8e36c84-84bd-11ec-a256-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Palace" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 2,, Indira Kumari Street, Krishnaveni Nagar,, Medavakkam, Chennai - 600100, Opposite Js Grand Palace" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9676505555 .
#
# <http://api.stardog.comschool#b8e36c85-84bd-11ec-9c09-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Office" ;
# 	:hasName "Narayana Olympiad School" ;
# 	:hasAddress "Narayana Group Of Schools, EB Road, Mogappair West, Chennai - 600037, Opp to E.B Office" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4569221446 .
#
# <http://api.stardog.comschool#b8e36c86-84bd-11ec-afd7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "D.R Supermarket" ;
# 	:hasName "Green Valley Central School" ;
# 	:hasAddress "No 2, Kalamegam Road, Mogappair West, chennai - 600037, Near The D.R Supermarket" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8683951149 .
#
# <http://api.stardog.comschool#b8e36c87-84bd-11ec-8cad-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Market" ;
# 	:hasName "Olive Public School" ;
# 	:hasAddress "No: 1, Second Main Road Sarvamangala Nagar, Chitlapakkam, Chennai - 600064, Near Nilgiris Super Market" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6573442291 .
#
# <http://api.stardog.comschool#b8e39398-84bd-11ec-b9be-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Chennai - 600044, Near Amarprakash" ;
# 	:hasName "Jain Public School" ;
# 	:hasAddress "Royal Castle Campus, Thirumudivakkam Main Road, Chromepet, Chennai - 600044, Near Amarprakash" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6795862787 .
#
# <http://api.stardog.comschool#b8e39399-84bd-11ec-a8b5-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Temple" ;
# 	:hasName "Narayana E Techno School" ;
# 	:hasAddress "No96 8th Block, 191st Street Muthamiz Nagar, Kodungaiyur, Chennai - 600118, Near Bhavani Amman Temple" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1543854175 .
#
# <http://api.stardog.comschool#b8e3939a-84bd-11ec-9f38-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Mosque" ;
# 	:hasName "Aadhithya International Pub.." ;
# 	:hasAddress "No 6, 2nd Main Road Royal Garden, Goparasanallur Village, Kattupakkam, Chennai - 600056, Near Mosque" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 7853838404 .
#
# <http://api.stardog.comschool#b8e3939b-84bd-11ec-8c5c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "MIT Play Ground" ;
# 	:hasName "S C S Matric Higher Seconda.." ;
# 	:hasAddress "No 30, Ramachandra Road ,Nehru Nagar, Chromepet, Chennai - 600044, Near MIT Play Ground" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2886979570 .
#
# <http://api.stardog.comschool#b8e3939c-84bd-11ec-8812-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Korattur" ;
# 	:hasName "Abs Global Smart School" ;
# 	:hasAddress "No 1, Vedhachalam Garaden, Korattur, Chennai - 600050" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8242887511 .
#
# <http://api.stardog.comschool#b8e3939d-84bd-11ec-bbeb-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Chennai - 600053, Aarthi Sweets" ;
# 	:hasName "PNET School" ;
# 	:hasAddress "No.616/2, Murugappa Reddy Street, Ambattur Ot Bus Terminus-Ambattur, Chennai - 600053, Aarthi Sweets" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2886456291 .
#
# <http://api.stardog.comschool#b8e3939e-84bd-11ec-9014-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Palace" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 2,, Indira Kumari Street, Krishnaveni Nagar,, Medavakkam, Chennai - 600100, Opposite Js Grand Palace" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5043087094 .
#
# <http://api.stardog.comschool#b8e3939f-84bd-11ec-a38f-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Office" ;
# 	:hasName "Narayana Olympiad School" ;
# 	:hasAddress "Narayana Group Of Schools, EB Road, Mogappair West, Chennai - 600037, Opp to E.B Office" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6815382198 .
#
# <http://api.stardog.comschool#b8e393a0-84bd-11ec-9162-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "D.R Supermarket" ;
# 	:hasName "Green Valley Central School" ;
# 	:hasAddress "No 2, Kalamegam Road, Mogappair West, chennai - 600037, Near The D.R Supermarket" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5321984006 .
#
# <http://api.stardog.comschool#b8e393a1-84bd-11ec-9058-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Market" ;
# 	:hasName "Olive Public School" ;
# 	:hasAddress "No: 1, Second Main Road Sarvamangala Nagar, Chitlapakkam, Chennai - 600064, Near Nilgiris Super Market" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 7133086930 .
#
# <http://api.stardog.comschool#b8e393a2-84bd-11ec-90d8-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Chennai - 600044, Near Amarprakash" ;
# 	:hasName "Jain Public School" ;
# 	:hasAddress "Royal Castle Campus, Thirumudivakkam Main Road, Chromepet, Chennai - 600044, Near Amarprakash" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4436617300 .
#
# <http://api.stardog.comschool#b8e393a3-84bd-11ec-a114-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "to Wheatcroft Road" ;
# 	:hasName "Serene Preschool & Daycare" ;
# 	:hasAddress "No 14/19, Sivaganga Main Road, Nungambakkam, Chennai - 600034, Adjacent to Wheatcroft Road" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1170749474 .
#
# <http://api.stardog.comschool#b8e393a4-84bd-11ec-9209-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "HDFC Bank Kelambakkam" ;
# 	:hasName "Kidzee Padur & Kelambakkam" ;
# 	:hasAddress "Plot No 2/24, Suseela Nagar Omr, Kelambakkam, Chennai - 603103, Near HDFC Bank Kelambakkam" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4143229099 .
#
# <http://api.stardog.comschool#b8e393a5-84bd-11ec-88eb-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "to Check Post" ;
# 	:hasName "D A Ve Baba Vidyalaya" ;
# 	:hasAddress "No 16, Vandikaran Street, Velacheri, Chennai - 600042, Opposite to Check Post" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 3755807046 .
#
# <http://api.stardog.comschool#b8e393a6-84bd-11ec-8f00-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Balaji Dental Hosiptal" ;
# 	:hasName "Kidzee" ;
# 	:hasAddress "No 1 Tranquill Nest, 3rd Main Road Kamakoti Nagar Annexe, Pallikaranai, Chennai - 600100, Near Balaji Dental Hosiptal" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 3233494748 .
#
# <http://api.stardog.comschool#b8e393a7-84bd-11ec-9e82-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Little Millennium" ;
# 	:hasAddress "Old No :13 New No :26, Vivekananda Street, Gandhi Nagar, Avadi, Chennai - 600054, Old Sales Tax Office Building" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9462731608 .
#
# <http://api.stardog.comschool#b8e393a8-84bd-11ec-979a-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Junction" ;
# 	:hasName "Vagisha Vidhyalaya" ;
# 	:hasAddress "Vagisha School, 1312/5, Outer Ring Road, Kundrathur, Chennai - 600069, Outer Ring Road /Earikarai Junction" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4500357750 .
#
# <http://api.stardog.comschool#b8e393a9-84bd-11ec-b719-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 2/212, 2nd Avenue, Prabala Nagar, ECR Road,, Vettuvankeni, Chennai - 600115" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9479597292 .
#
# <http://api.stardog.comschool#b8e393aa-84bd-11ec-9e62-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Sri Krish School" ;
# 	:hasAddress "No 1/191, Kundrathur Main Road Rajiv Gandhi Nagar, Kovur, Chennai - 600122" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1799195434 .
#
# <http://api.stardog.comschool#b8e3baa7-84bd-11ec-a5fe-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "St Peters College" ;
# 	:hasName "Abs Global Smart School" ;
# 	:hasAddress "No 1, Tonekala Road, Avadi, Chennai - 600054, Near St Peters College" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6906374842 .
#
# <http://api.stardog.comschool#b8e3baa8-84bd-11ec-b9d2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Sangar Narayanan Templ" ;
# 	:hasName "World Kids Play School" ;
# 	:hasAddress "No. 10/5, Durai Raj Street,Devaraj Nagar, Saligramam, Chennai - 600093, Near By Sangar Narayanan Temple" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1496553884 .
#
# <http://api.stardog.comschool#b8e3baa9-84bd-11ec-a54c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "to Wheatcroft Road" ;
# 	:hasName "Serene Preschool & Daycare" ;
# 	:hasAddress "No 14/19, Sivaganga Main Road, Nungambakkam, Chennai - 600034, Adjacent to Wheatcroft Road" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6843554177 .
#
# <http://api.stardog.comschool#b8e3baaa-84bd-11ec-9f3f-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "HDFC Bank Kelambakkam" ;
# 	:hasName "Kidzee Padur & Kelambakkam" ;
# 	:hasAddress "Plot No 2/24, Suseela Nagar Omr, Kelambakkam, Chennai - 603103, Near HDFC Bank Kelambakkam" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4384045889 .
#
# <http://api.stardog.comschool#b8e3baab-84bd-11ec-9adf-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "to Check Post" ;
# 	:hasName "D A Ve Baba Vidyalaya" ;
# 	:hasAddress "No 16, Vandikaran Street, Velacheri, Chennai - 600042, Opposite to Check Post" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8632561675 .
#
# <http://api.stardog.comschool#b8e3baac-84bd-11ec-a615-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Balaji Dental Hosiptal" ;
# 	:hasName "Kidzee" ;
# 	:hasAddress "No 1 Tranquill Nest, 3rd Main Road Kamakoti Nagar Annexe, Pallikaranai, Chennai - 600100, Near Balaji Dental Hosiptal" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 4638664202 .
#
# <http://api.stardog.comschool#b8e3baad-84bd-11ec-9024-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Little Millennium" ;
# 	:hasAddress "Old No :13 New No :26, Vivekananda Street, Gandhi Nagar, Avadi, Chennai - 600054, Old Sales Tax Office Building" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1167998242 .
#
# <http://api.stardog.comschool#b8e3baae-84bd-11ec-9d3c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Junction" ;
# 	:hasName "Vagisha Vidhyalaya" ;
# 	:hasAddress "Vagisha School, 1312/5, Outer Ring Road, Kundrathur, Chennai - 600069, Outer Ring Road /Earikarai Junction" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2516787285 .
#
# <http://api.stardog.comschool#b8e3baaf-84bd-11ec-b9b9-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 2/212, 2nd Avenue, Prabala Nagar, ECR Road,, Vettuvankeni, Chennai - 600115" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9035026434 .
#
# <http://api.stardog.comschool#b8e3e19f-84bd-11ec-a2a6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Sri Krish School" ;
# 	:hasAddress "No 1/191, Kundrathur Main Road Rajiv Gandhi Nagar, Kovur, Chennai - 600122" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5750966535 .
#
# <http://api.stardog.comschool#b8e3e1a0-84bd-11ec-b48e-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "St Peters College" ;
# 	:hasName "Abs Global Smart School" ;
# 	:hasAddress "No 1, Tonekala Road, Avadi, Chennai - 600054, Near St Peters College" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5111654695 .
#
# <http://api.stardog.comschool#b8e3e1a1-84bd-11ec-9629-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Sangar Narayanan Templ" ;
# 	:hasName "World Kids Play School" ;
# 	:hasAddress "No. 10/5, Durai Raj Street,Devaraj Nagar, Saligramam, Chennai - 600093, Near By Sangar Narayanan Temple" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9229206886 .
#
# <http://api.stardog.comschool#b8e3e1a2-84bd-11ec-8421-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Mudichur Road, Near to Natesan" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 2,, West Lakshmi Nagar, Mannivakkam, Chennai - 600048, Mudichur Road, Near to Natesan Bus Stop" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 7653937087 .
#
# <http://api.stardog.comschool#b8e3e1a3-84bd-11ec-b67d-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Vepery Fire Station" ;
# 	:hasName "Narayana Olympiad School" ;
# 	:hasAddress "No 15, EVK Sampath Road, Vepery, Chennai - 600007, Opposite Vepery Fire Station" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 5381618039 .
#
# <http://api.stardog.comschool#b8e3e1a4-84bd-11ec-bdf8-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "School" ;
# 	:hasName "Achariya Group Of Schools" ;
# 	:hasAddress "No. 329, 20th Street, Sri Krishna Nagar, Alapakkam, Chennai - 600116, Near Achariya Play School" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8802850360 .
#
# <http://api.stardog.comschool#b8e3e1a5-84bd-11ec-ba75-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Chennai - 600040, Near SMF" ;
# 	:hasName "Funkidz (Anna Nagar)" ;
# 	:hasAddress "No 2674 Y Block, 9TH Block 12th Main Road Shanthi Colony, Anna Nagar, Chennai - 600040, Near SMF" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1322600569 .
#
# <http://api.stardog.comschool#b8e3e1a6-84bd-11ec-bf8c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Bank Of Indi" ;
# 	:hasName "Little Expertz" ;
# 	:hasAddress "No 23, Engineer Sampath Garden Tsd Nagar Extn, Arumbakkam, Chennai - 600106, Near State Bank Of India" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 1182721947 .
#
# <http://api.stardog.comschool#b8e3e1a7-84bd-11ec-a685-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Towers" ;
# 	:hasName "Little Pearls Play School" ;
# 	:hasAddress "No 5, Ethiraj Amal Avenue Pillaiyar Koil Street, Kavankarai-Puzhal, Chennai - 600066, Near Mmm Towers" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 3472546965 .
#
# <http://api.stardog.comschool#b8e3e1a8-84bd-11ec-b59f-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "ACS Medical College" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 152, Poonamallee High Road, Poonamallee, Chennai - 600056, Near ACS Medical College" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 2242803524 .
#
# <http://api.stardog.comschool#b8e3e1a9-84bd-11ec-b599-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Near Bus Depot" ;
# 	:hasName "Star Play School Daycare" ;
# 	:hasAddress "No 02/144, 1st Main Road Ramachandra Nagar, Iyyappanthangal, Chennai - 600077, Near Bus Depot" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 7011941328 .
#
# <http://api.stardog.comschool#b8e3e1aa-84bd-11ec-a196-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Amethyst International Scho.." ;
# 	:hasAddress "No 298,, Karanai Main Road,Chithalapakkam,Ottiyampakkam,Chemenjari,, Navalur, Chennai - 600130, Near Dlf Garden City" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9173927573 .
#
# <http://api.stardog.comschool#b8e3e1ab-84bd-11ec-a0e0-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Anna Anadhi" ;
# 	:hasName "Annai Violet International .." ;
# 	:hasAddress "No 11, Red Hills Road, Ambattur, Chennai - 600053, Anna Anadhi Illam, Pudur" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9610797710 .
#
# <http://api.stardog.comschool#b8e3e1ac-84bd-11ec-abd6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "ACS Medical College" ;
# 	:hasName "Narayana E-Techno School" ;
# 	:hasAddress "No 152, Poonamallee High Road, Poonamallee, Chennai - 600056, Near ACS Medical College" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 8817681474 .
#
# <http://api.stardog.comschool#b8e3e1ad-84bd-11ec-8e58-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Near Bus Depot" ;
# 	:hasName "Star Play School Daycare" ;
# 	:hasAddress "No 02/144, 1st Main Road Ramachandra Nagar, Iyyappanthangal, Chennai - 600077, Near Bus Depot" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6084604639 .
#
# <http://api.stardog.comschool#b8e3e1ae-84bd-11ec-b283-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "" ;
# 	:hasName "Amethyst International Scho.." ;
# 	:hasAddress "No 298,, Karanai Main Road,Chithalapakkam,Ottiyampakkam,Chemenjari,, Navalur, Chennai - 600130, Near Dlf Garden City" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 9599548637 .
#
# <http://api.stardog.comschool#b8e408b0-84bd-11ec-a0f7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chennai" ;
# 	:hasLandmark "Anna Anadhi" ;
# 	:hasName "Annai Violet International .." ;
# 	:hasAddress "No 11, Red Hills Road, Ambattur, Chennai - 600053, Anna Anadhi Illam, Pudur" ;
# 	:hasLatitude 13.069061897342 ;
# 	:hasLongitude 80.243982476688 ;
# 	:hasPhone 6207286014 .
#
# <http://api.stardog.comschool#b8e408b1-84bd-11ec-95f1-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Ground Road T" ;
# 	:hasName "Manav Public School" ;
# 	:hasAddress "Plot No -1701, Naya Gaon, Chandigarh - 160103, Near Church  , Dashmesh Nagar Ramleela Ground Road T" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 5915328038 .
#
# <http://api.stardog.comschool#b8e408b2-84bd-11ec-94b4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "New India Senior Secondary .." ;
# 	:hasAddress "Near Main Market, Panchkula Sector 15, Panchkula - 134113, Opposite  House No-116" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 3539830790 .
#
# <http://api.stardog.comschool#b8e408b3-84bd-11ec-988d-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "tiny tots Foundation School" ;
# 	:hasAddress "Plot No .-5, Nr. Niper, Phase-10, Mohali, Mohali, Chandigarh - 160062" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 7768751311 .
#
# <http://api.stardog.comschool#b8e408b4-84bd-11ec-b1d4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Chandigarh - 160020, Opposite" ;
# 	:hasName "Tender Heart High School" ;
# 	:hasAddress "Chandigarh Sector 33b, Chandigarh - 160020, Opposite House Number" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8766747801 .
#
# <http://api.stardog.comschool#b8e408b5-84bd-11ec-8cb6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Mohali Sas Nagar" ;
# 	:hasName "Narayan E - Techno School" ;
# 	:hasAddress "Puda Gateway City, Sector 119, Mohali Sas Nagar, Mohali - 160055" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8147058078 .
#
# <http://api.stardog.comschool#b8e408b6-84bd-11ec-83cf-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Panchkula" ;
# 	:hasName "St Soldiers School" ;
# 	:hasAddress "Near Main Market, Sector 16, Panchkula, Panchkula - 134109" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 3840816757 .
#
# <http://api.stardog.comschool#b8e408b7-84bd-11ec-a928-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Near Congress Office" ;
# 	:hasName "Groots Pre School" ;
# 	:hasAddress "Green Park Colony, Lohgarh Road, Zirakpur HO, Zirakpur - 140603, Near Congress Office" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 1298958460 .
#
# <http://api.stardog.comschool#b8e408b8-84bd-11ec-841c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Derabassi" ;
# 	:hasName "Global Wisdom International.." ;
# 	:hasAddress "Dashmesh Nagar, Derabassi Barwala Road, Derabassi, Zirakpur - 140507" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 3161371450 .
#
# <http://api.stardog.comschool#b8e408b9-84bd-11ec-8009-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Of Kothi Number 17" ;
# 	:hasName "Sherwood Convent School" ;
# 	:hasAddress "SAS Nagar Mohali, Chandigarh Sector 59 Phase 4, Chandigarh - 160059, In Front Of Kothi Number 173" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 4305362438 .
#
# <http://api.stardog.comschool#b8e408ba-84bd-11ec-b059-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Near Greater Mohali, Near Thunder Zone" ;
# 	:hasName "Oakridge International Scho.." ;
# 	:hasAddress "Landran, Mohali - 140307, Near Greater Mohali, Near Thunder Zone Amusement Park" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 5053621282 .
#
# <http://api.stardog.comschool#b8e408bb-84bd-11ec-89f4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Near Yadav Bhavan" ;
# 	:hasName "Brilliance World School" ;
# 	:hasAddress "Site Number 1,Sector 12, Panchkula, Panchkula - 134109, Near Yadav Bhavan" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 6024081982 .
#
# <http://api.stardog.comschool#b8e408bc-84bd-11ec-82de-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "Saint Soldier International.." ;
# 	:hasAddress "Sector 28-B, Chandigarh Sector 28b, Chandigarh - 160102" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 2771706005 .
#
# <http://api.stardog.comschool#b8e408bd-84bd-11ec-8865-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Modern Housing Complex" ;
# 	:hasName "D C Montessori Senior Secon.." ;
# 	:hasAddress "Pocket No. 2 & 3, Mani Majra, Chandigarh - 160101, Near Modern Housing Complex" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 5405839500 .
#
# <http://api.stardog.comschool#b8e408be-84bd-11ec-94dc-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Sector 37d" ;
# 	:hasName "Stepping Stones Senior Seco.." ;
# 	:hasAddress "Stepping Stones, Sector 37d, Chandigarh - 160036" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 3333757022 .
#
# <http://api.stardog.comschool#b8e408bf-84bd-11ec-a7e2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "Sanjivni Preparatory School.." ;
# 	:hasAddress "House Number  44, Sector 11, Chandigarh - 160011, Behind Sector 11 D Market and Half Kilometre Away From Police Station" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 2366106916 .
#
# <http://api.stardog.comschool#b8e408c0-84bd-11ec-a397-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Panchkula - 134108, NEAR GURUDWARA" ;
# 	:hasName "D.c. MODEL Senior Secondary.." ;
# 	:hasAddress "Panchkula, Main Market, Panchkula Sector 7, Panchkula - 134108, NEAR GURUDWARA" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8969433757 .
#
# <http://api.stardog.comschool#b8e42fd3-84bd-11ec-89b3-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Chandigarh - 160022, Piccadily Cinema" ;
# 	:hasName "Rise Campus Chandigarh" ;
# 	:hasAddress "Sco 91 ,92, 93, Ground Floor, Chandigarh Sector 34a, Chandigarh - 160022, Piccadily Cinema" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 7736577710 .
#
# <http://api.stardog.comschool#b8e42fd4-84bd-11ec-95c4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Sector 20" ;
# 	:hasName "Solitaire International Sch.." ;
# 	:hasAddress "Opp. Suncity Parikarma, Sector 20, Panchkula - 134116" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 1320811818 .
#
# <http://api.stardog.comschool#b8e42fd5-84bd-11ec-9139-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Mohali - 140103, Near" ;
# 	:hasName "International Public School" ;
# 	:hasAddress "Paprali Road, Kurali, Mohali - 140103, Near Over  Bridge" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 5063885039 .
#
# <http://api.stardog.comschool#b8e42fd6-84bd-11ec-b099-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Mohali - 140301, Near Gurudwara" ;
# 	:hasName "Diamond Public School" ;
# 	:hasAddress "Mundi Kharar, Lic Colony Road, Kharar, Mohali - 140301, Near Gurudwara" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 2674536789 .
#
# <http://api.stardog.comschool#b8e42fd7-84bd-11ec-8257-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Behind Bangalore University" ;
# 	:hasName "VSS International Public Sc.." ;
# 	:hasAddress "No:78, Outer Ring Road, Nagadevanahalli, Bangalore - 560060, Behind Bangalore University" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 5345278469 .
#
# <http://api.stardog.comschool#b8e42fd8-84bd-11ec-9863-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Bangalore - 560024, Near" ;
# 	:hasName "St. Johns School" ;
# 	:hasAddress "Bhuvaneshwari Nagar,Kempapura,Coffee Board Layout, Hebbal, Bangalore - 560024, Near Water Tank" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 5971202113 .
#
# <http://api.stardog.comschool#b8e42fd9-84bd-11ec-9a39-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Bangalore - 562110, Opposite" ;
# 	:hasName "The School For Global Minds" ;
# 	:hasAddress "Brigade Orchards, Devanahalli, Bangalore - 562110, Opposite Aspen Block" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 8690312165 .
#
# <http://api.stardog.comschool#b8e42fda-84bd-11ec-95f6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "" ;
# 	:hasName "Carmel Public School" ;
# 	:hasAddress "No 2, 5th Cross , M S Layout, Jarganahalli, Jp Nagar 6th Phase, Bangalore - 560078, Near Sarakki Signal" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 2729779060 .
#
# <http://api.stardog.comschool#b8e42fdb-84bd-11ec-9ec6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Bangalore - 560097, Near" ;
# 	:hasName "Basil Woods Nature School" ;
# 	:hasAddress "MS Palya Road, Lakshmipura Cross, Bangalore - 560097, Near Sambhram College" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 2331443514 .
#
# <http://api.stardog.comschool#b8e42fdc-84bd-11ec-a059-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Sarjapura Attibee Road" ;
# 	:hasName "Brs Global School" ;
# 	:hasAddress "No 317/2, Bidaraguppe Village, Attibele, Bangalore - 562107, Sarjapura Attibee Road" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 3314365796 .
#
# <http://api.stardog.comschool#b8e42fdd-84bd-11ec-bacf-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Sylvan V" ;
# 	:hasName "St Joseph Chaminade Academy" ;
# 	:hasAddress "No. 1, Anekal Taluk, Deepahalli, Anandpura Village, Bommasandra, Bangalore - 560099, Opposite to Concorde Sylvan View Apartments" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 2337180205 .
#
# <http://api.stardog.comschool#b8e42fde-84bd-11ec-9812-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Care" ;
# 	:hasName "Bs International School" ;
# 	:hasAddress "No 228/4, S. Bingipura, Electronic City Phase 1, Bangalore - 560100, Near Holistic Life Care" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 7331567811 .
#
# <http://api.stardog.comschool#b8e42fdf-84bd-11ec-9c3b-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Gunjur Bus Stop" ;
# 	:hasName "Chistiya International Scho.." ;
# 	:hasAddress "Gunjur, Whitefield-Sarjapur Road, Varthur, Bangalore - 560087, Near Gunjur Bus Stop" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 4243780602 .
#
# <http://api.stardog.comschool#b8e42fe0-84bd-11ec-a7fe-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "" ;
# 	:hasName "MS Dhoni Global School" ;
# 	:hasAddress "No 47/1A,1B, Hsr Extension(South), Kudulu Gate, Bangalore - 560068, Opposite to Cadenza Apartments" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 1179307915 .
#
# <http://api.stardog.comschool#b8e42fe1-84bd-11ec-98de-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Road, Tarabanahalli, Bangalore - 560090" ;
# 	:hasName "The Millennium School" ;
# 	:hasAddress "Sri Jnanagiri Educational Trust, No.57, Hessarghatta Main Road, Tarabanahalli, Bangalore - 560090" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 1115781837 .
#
# <http://api.stardog.comschool#b8e42fe2-84bd-11ec-a324-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Near Shankarnag Circle" ;
# 	:hasName "Holy Child Convent" ;
# 	:hasAddress "No 1133/44,, 9th Cross, Banashankari 1st Stage, Bangalore - 560050, Near Shankarnag Circle" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 5578618345 .
#
# <http://api.stardog.comschool#b8e42fe3-84bd-11ec-847e-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Adhishwar Home Appliances" ;
# 	:hasName "Divine School" ;
# 	:hasAddress "No.640, 1st Main Road, Yeshwanthpur, Bangalore - 560022, Opposite Adhishwar Home Appliances" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 2716700091 .
#
# <http://api.stardog.comschool#b8e42fe4-84bd-11ec-963c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Opposite Shobha Apartments" ;
# 	:hasName "The Home School" ;
# 	:hasAddress "CA No.4, U M Kaval, Kanakapura Road, Bangalore - 560062, Opposite Shobha Apartments" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 2368096736 .
#
# <http://api.stardog.comschool#b8e456e2-84bd-11ec-b3e5-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Devanahalli" ;
# 	:hasName "Mvm Central School" ;
# 	:hasAddress "Kannamangala, Kempegowda International Airport Road, Devanahalli, Bangalore - 562110" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 5747948577 .
#
# <http://api.stardog.comschool#b8e456e3-84bd-11ec-b306-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "" ;
# 	:hasName "Mount Litera Zee School" ;
# 	:hasAddress "No 40/123, Kadugodi, Bangalore - 560067, Near Satya Sai Baba Ashram and Skylark Arcade" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 5078374519 .
#
# <http://api.stardog.comschool#b8e456e4-84bd-11ec-a75f-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "" ;
# 	:hasName "Lady Vailankanni Group Of I.." ;
# 	:hasAddress "No 175/2, Lady Vailankanni Road, Varthur, Bangalore - 560087, Behind Varthur Vinayaka Theater,Near Varthur Government Hospital" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 6753744355 .
#
# <http://api.stardog.comschool#b8e456e5-84bd-11ec-89e7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Rml Law College" ;
# 	:hasName "Radcliffe School" ;
# 	:hasAddress "15th Milestone, Gottigere, Bannerghatta Road, Bangalore - 560076, Next to Rml Law College" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 3519433160 .
#
# <http://api.stardog.comschool#b8e456e6-84bd-11ec-b931-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "" ;
# 	:hasName "SJES Institutions" ;
# 	:hasAddress "No 4, Medahalli,Old Madras Road, Virgonagar, Bangalore - 560049, Opposite to RTO" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 4717893372 .
#
# <http://api.stardog.comschool#b8e456e7-84bd-11ec-bc21-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Bangalore" ;
# 	:hasLandmark "Chadapura  Anekal Road" ;
# 	:hasName "EuroKids" ;
# 	:hasAddress "HIG B 46, Surya City Phase 1 Chandapura, Chandapura, Bangalore - 560081, Near Chadapura  Anekal Road" ;
# 	:hasLatitude 12.96679387 ;
# 	:hasLongitude 77.59840577 ;
# 	:hasPhone 1439126605 .
#
# <http://api.stardog.comschool#b8e456e8-84bd-11ec-8b5e-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Near Congress Office" ;
# 	:hasName "Groots Pre School" ;
# 	:hasAddress "Green Park Colony, Lohgarh Road, Zirakpur HO, Zirakpur - 140603, Near Congress Office" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8266378387 .
#
# <http://api.stardog.comschool#b8e456e9-84bd-11ec-a1c4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "Saint Soldier International.." ;
# 	:hasAddress "Sector 28-B, Chandigarh Sector 28b, Chandigarh - 160102" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8482034748 .
#
# <http://api.stardog.comschool#b8e456ea-84bd-11ec-8845-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Panchkula - 134108, NEAR GURUDWARA" ;
# 	:hasName "D.c. MODEL Senior Secondary.." ;
# 	:hasAddress "Panchkula, Main Market, Panchkula Sector 7, Panchkula - 134108, NEAR GURUDWARA" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 1067332879 .
#
# <http://api.stardog.comschool#b8e456eb-84bd-11ec-b265-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Modern Housing Complex" ;
# 	:hasName "D C Montessori Senior Secon.." ;
# 	:hasAddress "Pocket No. 2 & 3, Mani Majra, Chandigarh - 160101, Near Modern Housing Complex" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 1813374572 .
#
# <http://api.stardog.comschool#b8e456ec-84bd-11ec-9cf6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "" ;
# 	:hasName "Sanjivni Preparatory School.." ;
# 	:hasAddress "House Number  44, Sector 11, Chandigarh - 160011, Behind Sector 11 D Market and Half Kilometre Away From Police Station" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 6582496050 .
#
# <http://api.stardog.comschool#b8e456ed-84bd-11ec-8d41-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Sector 37d" ;
# 	:hasName "Stepping Stones Senior Seco.." ;
# 	:hasAddress "Stepping Stones, Sector 37d, Chandigarh - 160036" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 2494092253 .
#
# <http://api.stardog.comschool#b8e456ee-84bd-11ec-b2ba-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Mohali - 140103, Near" ;
# 	:hasName "International Public School" ;
# 	:hasAddress "Paprali Road, Kurali, Mohali - 140103, Near Over  Bridge" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 5123294121 .
#
# <http://api.stardog.comschool#b8e456ef-84bd-11ec-b202-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Chandigarh" ;
# 	:hasLandmark "Sector 20" ;
# 	:hasName "Solitaire International Sch.." ;
# 	:hasAddress "Opp. Suncity Parikarma, Sector 20, Panchkula - 134116" ;
# 	:hasLatitude 30.72377802 ;
# 	:hasLongitude 76.78114776 ;
# 	:hasPhone 8013037052 .
#
# <http://api.stardog.comschool#b8e456f0-84bd-11ec-a094-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Chandigarh" ;
# ...
# 	:hasPhone 2914627227 .
#
# <http://api.stardog.comschool#b8e62bd3-84bd-11ec-b8f9-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Kanadia" ;
# 	:hasName "Sardar Patel International .." ;
# 	:hasAddress "Khatri Khedi, Kanadia Main Road, Kanadia, Indore - 452016" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 1973062067 .
#
# <http://api.stardog.comschool#b8e62bd4-84bd-11ec-a9d7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Annapurna Road" ;
# 	:hasName "Little Diamonds Pre School" ;
# 	:hasAddress "Neminagar Extension No 60, Kesar Baugh Road, Annapurna Road, Indore - 452009" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 8948837057 .
#
# <http://api.stardog.comschool#b8e62bd5-84bd-11ec-8b77-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Parivahan Nagar, Near" ;
# 	:hasName "Shri Anand H.S. School" ;
# 	:hasAddress "Dwarkapuri, Indore - 452013, Parivahan Nagar, Near Hava Banglow" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 8766619495 .
#
# <http://api.stardog.comschool#b8e62bd6-84bd-11ec-8426-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Indore - 452010, Near" ;
# 	:hasName "The Bhavans Prominent Inter.." ;
# 	:hasAddress "The Bhavans, Nipania Indore, Indore - 452010, Near Bombay Hospital" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 1953837447 .
#
# <http://api.stardog.comschool#b8e62bd7-84bd-11ec-b71b-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "" ;
# 	:hasName "Ecs Bagless School" ;
# 	:hasAddress "Mr-3, Plot No 408-411, Behind Pioneer College, Mahalaxmi Nagar, Indore - 452010, Near Suncity" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 7317438097 .
#
# <http://api.stardog.comschool#b8e62bd8-84bd-11ec-ad12-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Apollo DB City" ;
# 	:hasName "The Kingston Junior" ;
# 	:hasAddress "Plot No 43 /7/1/2, Behind Namarta Garden, Nipania Indore, Indore - 452010, Near Bcm Paradise & Apollo DB City" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 5590985825 .
#
# <http://api.stardog.comschool#b8e652bb-84bd-11ec-bcae-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Airport Road Indore" ;
# 	:hasName "Lakewood International Scho.." ;
# 	:hasAddress "140/1,Bisnavda, Near Cement Bricks Factory, Rinjlai, Indore - 453112, Airport Road Indore" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 8751129341 .
#
# <http://api.stardog.comschool#b8e652bc-84bd-11ec-9b27-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Pump" ;
# 	:hasName "Dr. Vishwanath Karad World .." ;
# 	:hasAddress "Gat No. 296/297, Gandhi Nagar, Gandhi Nagar, Indore - 453112, Opp. to HP Petrol Pump" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 5461701903 .
#
# <http://api.stardog.comschool#b8e652bd-84bd-11ec-a347-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Indore - 452018, Near" ;
# 	:hasName "Sherringwoods World School" ;
# 	:hasAddress "04, Gyanas Park, Kanadiya Road, Telephone Nagar, Indore - 452018, Near Swayamber Garden" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 3098968638 .
#
# <http://api.stardog.comschool#b8e652be-84bd-11ec-96ba-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Indore - 452001, Nr" ;
# 	:hasName "The Vedansh International S.." ;
# 	:hasAddress "Airport Road, Indore - 452001, Nr.Police Station" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 1684075291 .
#
# <http://api.stardog.comschool#b8e652bf-84bd-11ec-be93-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Indore - 452010, Part II" ;
# 	:hasName "Daisy Dales School" ;
# 	:hasAddress "19, Scheme No 78, Vijay Nagar, Indore - 452010, Part II" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 3340302029 .
#
# <http://api.stardog.comschool#b8e652c0-84bd-11ec-b180-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "National Bank AT" ;
# 	:hasName "Castlewood International Pr.." ;
# 	:hasAddress "26 , Indra Gandhi Nagar, RTO Road, Kesar Baug Road, Indore - 452009, Opposite Punjab National Bank ATM" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 4306697302 .
#
# <http://api.stardog.comschool#b8e652c1-84bd-11ec-9dc5-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "" ;
# 	:hasName "Jagruti Higher Secondary Sc.." ;
# 	:hasAddress "9/3 Manormaganj, Manoramaganj, Indore - 452001, Near Geeta Bhavan Temple" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 6440368124 .
#
# <http://api.stardog.comschool#b8e652c2-84bd-11ec-8947-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Indore" ;
# 	:hasLandmark "Indore" ;
# 	:hasName "Maa Umiya Patidar Trust" ;
# 	:hasAddress "Umiyadham, Rangwasa, Rau Rangwasa Road, Rau, Indore - 453331, Umiiyadham" ;
# 	:hasLatitude 22.72118074 ;
# 	:hasLongitude 75.85706582 ;
# 	:hasPhone 2632645343 .
#
# <http://api.stardog.comschool#b8e679e1-84bd-11ec-af8c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641659, Near" ;
# 	:hasName "Kovai Public School" ;
# 	:hasAddress "Elachipalayam Road, Karumathampatti, Coimbatore - 641659, Near Chenniyandavar Kovil" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 4755348970 .
#
# <http://api.stardog.comschool#b8e679e2-84bd-11ec-93d4-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641048, Kurumbapalayam Road" ;
# 	:hasName "The Ideal Mount Litera Zee .." ;
# 	:hasAddress "No 1081 / 2, Ideal Nagar, Kalapatti, Coimbatore - 641048, Kurumbapalayam Road" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 3591185023 .
#
# <http://api.stardog.comschool#b8e679e3-84bd-11ec-9bf7-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Behind Manis Theatre," ;
# 	:hasName "Prodigy International Monte.." ;
# 	:hasAddress "Door No 2A/1,, Andal Street, Lakshmipuram,, Peelamedu, Coimbatore - 641004, Behind Manis Theatre," ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 2624915423 .
#
# <http://api.stardog.comschool#b8e679e4-84bd-11ec-b65c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Rotary Community Hal" ;
# 	:hasName "Junior Delhi Public School" ;
# 	:hasAddress "No 48, 2nd West Cross, Bharthi Colony, Bharathi Colony-Peelamedu, Coimbatore - 641004, Opp. Rotary Community Hall" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 1039983137 .
#
# <http://api.stardog.comschool#b8e679e5-84bd-11ec-a452-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Little Flower Matriculation.." ;
# 	:hasAddress "Vellakinar Village,, Kurudampalayam, Vellakinar, Coimbatore - 641029, Near Manchester School" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7140400070 .
#
# <http://api.stardog.comschool#b8e679e6-84bd-11ec-93a2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Sri Sathya Sai Vidhya Niket.." ;
# 	:hasAddress "2/182 A Norena Garden, Vadavalli, Coimbatore - 641041" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 6478628160 .
#
# <http://api.stardog.comschool#b8e679e7-84bd-11ec-8938-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Kennedy Matriculation Highe.." ;
# 	:hasAddress "No 2,, Muthiazhagan Nagar,Trichy Road, Sulur, Coimbatore - 641402, Opp Union Bank" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 2086805035 .
#
# <http://api.stardog.comschool#b8e679e8-84bd-11ec-9586-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Behind Abirami Hospital" ;
# 	:hasName "Tiny Wings Play School" ;
# 	:hasAddress "237 E 2, Anna Nagar, Sundarapuram, Coimbatore - 641024, Behind Abirami Hospital" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7408490984 .
#
# <http://api.stardog.comschool#b8e679e9-84bd-11ec-afe6-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Near GKNM Hospital" ;
# 	:hasName "Little Champ Daycare and Pl.." ;
# 	:hasAddress "No 2, Rangammal Kovil Street, Papanaickenpalayam, Coimbatore - 641037, Near GKNM Hospital" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 5705974269 .
#
# <http://api.stardog.comschool#b8e679ea-84bd-11ec-b13c-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Mettupalayam" ;
# 	:hasName "Svgv Matriculation Higher S.." ;
# 	:hasAddress "Mtp Road, Mettupalayam, Coimbatore - 641301" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 1171305672 .
#
# <http://api.stardog.comschool#b8e679eb-84bd-11ec-8070-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641045, Thirupathi Mess" ;
# 	:hasName "Little Miracle Academy" ;
# 	:hasAddress "No 41, Balaji Nagar, Ramanathapuram Coimbatore, Coimbatore - 641045, Thirupathi Mess" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 8875848386 .
#
# <http://api.stardog.comschool#b8e6a0e6-84bd-11ec-817e-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641004, Opposite Suguna" ;
# 	:hasName "Rathinam International Publ.." ;
# 	:hasAddress "Avinashi Road, Peelamedu, Coimbatore - 641004, Opposite Suguna Kalyana Mandapam" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 6852684231 .
#
# <http://api.stardog.comschool#b8e6a0e7-84bd-11ec-b7c1-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Einstein Kids International.." ;
# 	:hasAddress "43, Hindustan Avenue,Nava India Mainroad, Sowripalayam, Coimbatore - 641028, Near Hindustan College" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7837514220 .
#
# <http://api.stardog.comschool#b8e6a0e8-84bd-11ec-8687-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Dhyan Accupuncture Hospital" ;
# 	:hasName "Happy Home Nursery & Primar.." ;
# 	:hasAddress "No 36/37/38, Mahalakshmi Gardens, Cheran Ma Nagar, Coimbatore - 641035, Dhyan Accupuncture Hospital" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 6157216549 .
#
# <http://api.stardog.comschool#b8e6a0e9-84bd-11ec-8698-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Kgisl Platina Appartment" ;
# 	:hasName "Venba Kids" ;
# 	:hasAddress "Kgisl Platina Apartment, Keeranatham Road, Saravanampatti, Coimbatore - 641035, Kgisl Platina Appartment" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 4349784351 .
#
# <http://api.stardog.comschool#b8e6a0ea-84bd-11ec-b3af-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "to Pulakkatu Thottam" ;
# 	:hasName "Eurokids" ;
# 	:hasAddress "No 1, Elachipalayam Road, Somanur, Coimbatore - 641668, Karumathampatti to Pulakkatu Thottam" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 9117104920 .
#
# <http://api.stardog.comschool#b8e6a0eb-84bd-11ec-8ced-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641005, Near Central Studio" ;
# 	:hasName "Little Ville" ;
# 	:hasAddress "17, Thirunagar, Dhanalakshmipuram North, Singanallur, Coimbatore - 641005, Near Central Studio Bus Stop" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 3970777059 .
#
# <http://api.stardog.comschool#b8e6a0ec-84bd-11ec-8479-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Sai Gurukulam International.." ;
# 	:hasAddress "No B-91, Cheran Ma Nagar, Coimbatore - 641035, Near Third Bus Stop, Siva Temple Cheran Ma Nagar,Near Shiva Temple" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 1355982578 .
#
# <http://api.stardog.comschool#b8e6a0ed-84bd-11ec-a91e-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641035" ;
# 	:hasName "Ruby Matric Higher Secondar.." ;
# 	:hasAddress "New Keeranatham Road, Saravanampatti, Coimbatore - 641035, Near Kgisl" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 1440486267 .
#
# <http://api.stardog.comschool#b8e6a0ee-84bd-11ec-a8ef-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Velandipalayam" ;
# 	:hasName "Kidgees Play School And Day.." ;
# 	:hasAddress "No.30, Ambedkar road, Velandipalayam, Coimbatore - 641025" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 1016357028 .
#
# <http://api.stardog.comschool#b8e6c7f0-84bd-11ec-b8c5-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Nursery ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641005, Near Central Studio" ;
# 	:hasName "Little Ville" ;
# 	:hasAddress "17, Thirunagar, Dhanalakshmipuram North, Singanallur, Coimbatore - 641005, Near Central Studio Bus Stop" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7553819243 .
#
# <http://api.stardog.comschool#b8e6c7f1-84bd-11ec-98f2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Secondary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "" ;
# 	:hasName "Sai Gurukulam International.." ;
# 	:hasAddress "No B-91, Cheran Ma Nagar, Coimbatore - 641035, Near Third Bus Stop, Siva Temple Cheran Ma Nagar,Near Shiva Temple" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 4861014853 .
#
# <http://api.stardog.comschool#b8e6c7f2-84bd-11ec-8897-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Coimbatore - 641035" ;
# 	:hasName "Ruby Matric Higher Secondar.." ;
# 	:hasAddress "New Keeranatham Road, Saravanampatti, Coimbatore - 641035, Near Kgisl" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7130692634 .
#
# <http://api.stardog.comschool#b8e6c7f3-84bd-11ec-afc2-9828a61c799d> a <http://api.stardog.comschool> ;
# 	:hasschoolType    "Primary ";
# 	:hasLocation "Coimbatore" ;
# 	:hasLandmark "Velandipalayam" ;
# 	:hasName "Kidgees Play School And Day.." ;
# 	:hasAddress "No.30, Ambedkar road, Velandipalayam, Coimbatore - 641025" ;
# 	:hasLatitude 11.01165601 ;
# 	:hasLongitude 76.96874072 ;
# 	:hasPhone 7545677653 .

# %%
connection_details = {
  'endpoint': 'http://localhost:5820',
  'username': 'admin',
  'password': 'admin'
}

database_name = 'massive_insertion_v3'

# with stardog.Admin(**connection_details) as admin:
#     if database_name in [db.name for db in admin.databases()]:
#         admin.database(database_name).drop()
#     db = admin.new_database(database_name)
    
conn = stardog.Connection(database_name, **connection_details)
conn.begin()
# Out:
# '603f9cd5-317a-4ae2-8c68-fea56f943198'

# %%
#conn.add(stardog.content.File('C:/xampp/htdocs/python/dummy_dataset.ttl'))
conn.add(stardog.content.File('school.ttl'))

conn.commit()

# %%
conn.__exit__()
